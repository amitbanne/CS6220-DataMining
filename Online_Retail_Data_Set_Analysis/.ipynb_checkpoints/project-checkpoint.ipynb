# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from sklearn.cluster import KMeans,AgglomerativeClustering
import csv
import numpy as np
import time
import calendar
import math
import statsmodels

# %% [markdown]
# ### Importing Data into Pandas Data Frame for Exploratory Analysis

# %%
#loading file to pandas dataframe
retail_landing_df = pd.read_excel('Online_Retail.xlsx')
print("File converted to dataframe")
# Out:
# File converted to dataframe

# %% [markdown]
# ### Exploratory Analysis Of Data Set

# %%
# printing structure of dataframe 
print(retail_landing_df.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# getting summary statistics for numeric columns
print(retail_landing_df.describe())
print("\n")
print("\n")
print(retail_landing_df[['UnitPrice']].describe())
print("\n")
print("\n")
print(retail_landing_df[['Quantity']].describe())
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000
#
#
#
#
#            UnitPrice
# count  541909.000000
# mean        4.611114
# std        96.759853
# min    -11062.060000
# 25%         1.250000
# 50%         2.080000
# 75%         4.130000
# max     38970.000000
#
#
#
#
#             Quantity
# count  541909.000000
# mean        9.552250
# std       218.081158
# min    -80995.000000
# 25%         1.000000
# 50%         3.000000
# 75%        10.000000
# max     80995.000000

# %%
# computing new columns. Total price is equal to unit price * quantity 
# will be used later to compute avg price vs avg quantity 

retail_landing_df['TotalPrice'] = retail_landing_df['Quantity'] * retail_landing_df['UnitPrice']
print(retail_landing_df.head(5))
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
#1 Identify clusters of purchased items by quantity (E.g.: at least 10, 25 etc.; or buckets i.e.
#  0-20, 20-40, 40-60 etc.)

#Preparing dataframe for question 1 
q1_quant_data = retail_landing_df[['StockCode','Quantity','Description']]

# Finding out the quantity vs number of items which fall in that category
q1_quant_data_agg = q1_quant_data.groupby(['StockCode','Description']).sum().reset_index()
q1_quant_data_agg_quants = list(q1_quant_data['Quantity'])
q1_quant_data_agg_scode = list(q1_quant_data['StockCode'])


# top 10 items 
# Purpose : To get top 10 Items by quantity
# Input : A dataframe consisiting of two columns , Stock Code and Quantity
# Ouptut: Top 10 products by quantity 

def getTop10ByQuantity(df, ascending=True):
    q1_quant_data_agg_topk = df.sort_values(['Quantity'],ascending=ascending).head(10)
    return q1_quant_data_agg_topk


# plotting the values
bins = range(0,30)
plt.hist(q1_quant_data_agg_quants, bins=bins)
plt.xlabel("Quantity")
plt.ylabel("Number of Items")
plt.show()



# Top 10 items purchased by customers
print("Top 10 Items Most by Quantity")
print("\n")
top_10_by_quantity = getTop10ByQuantity(q1_quant_data_agg, ascending=False)
print(top_10_by_quantity.to_string(index=False))

print("\n")
print("\n")

# 10 items least purchased by customers
print("10 Items Least Purchased by Quantity")
print("\n")
top_10_by_quantity = getTop10ByQuantity(q1_quant_data_agg,ascending=True)
print(top_10_by_quantity.to_string(index=False))



#### Identifying items purchased with certain quantity range 

def getClusterByQuantRange(minQuantRange,maxQuantRange):
    q1_quant_data_agg_range = q1_quant_data_agg[(q1_quant_data_agg.Quantity<=maxQuantRange) & (q1_quant_data_agg.Quantity>=minQuantRange)]
    return q1_quant_data_agg_range['StockCode']
# Out:
# Top 10 Items Most by Quantity
#
#
# StockCode                         Description  Quantity
#    84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
#   85099B             JUMBO BAG RED RETROSPOT     47363
#    84879       ASSORTED COLOUR BIRD ORNAMENT     36381
#    22197                      POPCORN HOLDER     36334
#    21212     PACK OF 72 RETROSPOT CAKE CASES     36039
#   85123A  WHITE HANGING HEART T-LIGHT HOLDER     35025
#    23084                  RABBIT NIGHT LIGHT     30680
#    22492             MINI PAINT SET VINTAGE      26437
#    22616          PACK OF 12 LONDON TISSUES      26315
#    21977  PACK OF 60 PINK PAISLEY CAKE CASES     24753
#
#
#
#
# 10 Items Least Purchased by Quantity
#
#
# StockCode                   Description  Quantity
#    23005  printing smudges/thrown away    -19200
#    23003  Printing smudges/thrown away     -9058
#   72140F                    throw away     -5368
#   79323W        Unsaleable, destroyed.     -4830
#    20713  wrongly marked. 23343 in box     -3100
#    84598                         check     -3000
#    23270        incorrect stock entry.     -2880
#  79323LP        Unsaleable, destroyed.     -2618
#    22617          mouldy, thrown away.     -2600
#    72732        thrown away-can't sell     -2472

# %%
#2 Identify clusters of purchased items by price range


#Preparing dataframe for question 2 
q1_price_data = retail_landing_df[['StockCode','UnitPrice','Description']]

# Finding out the quantity vs number of items which fall in that category
q1_price_data_agg = q1_price_data.drop_duplicates()#groupby(['StockCode','Description','UnitPrice']).
q1_price_data_agg_prices = list(q1_price_data['UnitPrice'])


# top 10 items 
# Purpose : To get top 10 Items by price
# Input : A dataframe consisiting of two columns , Stock Code and Quantity
# Ouptut: Top 10 products by quantity 

def getTop10ByPrice(df, ascending=True):
    q1_quant_data_agg_topk = df.sort_values(['UnitPrice'],ascending=ascending)
    return q1_quant_data_agg_topk


# getting top 10 priced items
print("Top 10 Priced Items")
print("\n")
top_k_price = getTop10ByPrice(q1_price_data_agg,ascending=False)
print(top_k_price.groupby(['StockCode', 'Description']).agg('max').reset_index().sort_values(['UnitPrice'], ascending=False).head(20))

print("\n")
print("\n")

# getting top 10 least priced items
print("10 Least priced items")
print("\n")
least_k_price = getTop10ByPrice(q1_price_data_agg)
print(least_k_price.head(20))

# plotting the values
bins = range(0,30)
plt.hist(q1_price_data_agg_prices, bins=bins)
plt.xlabel("Price")
plt.ylabel("Number of Items")
plt.show()

# A more detailed view  by avoiding values after 15 since they are few in number

bins = range(0,15,2)
plt.hist(q1_price_data_agg_prices, bins=bins)
plt.xlabel("Price")
plt.ylabel("Number of Items")
plt.show()
# Out:
# Top 10 Priced Items
#
#
#          StockCode                         Description  UnitPrice
# 4781             M                              Manual   38970.00
# 4762     AMAZONFEE                          AMAZON FEE   17836.46
# 4763             B                     Adjust bad debt   11062.06
# 4783          POST                             POSTAGE    8142.75
# 4780           DOT                      DOTCOM POSTAGE    4505.17
# 4767             D                            Discount    1867.86
# 4766          CRUK                     CRUK Commission    1100.44
# 4764  BANK CHARGES                        Bank Charges    1050.15
# 1553         22502      PICNIC BASKET WICKER 60 PIECES     649.50
# 4784             S                             SAMPLES     570.00
# 1730         22656        VINTAGE BLUE KITCHEN CABINET     295.00
# 1728         22655         VINTAGE RED KITCHEN CABINET     295.00
# 1927         22826       LOVE SEAT ANTIQUE WHITE METAL     195.00
# 1929         22828        REGENCY MIRROR WITH SHUTTERS     165.00
# 1928         22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD     165.00
# 4765            C2                            CARRIAGE     150.00
# 1923         22823       CHEST NATURAL WOOD 20 DRAWERS     125.00
# 1934         22833         HALL CABINET WITH 3 DRAWERS     100.00
# 2223         23064              CINDERELLA CHANDELIER       99.96
# 637          21473   SWEETHEART CREAM STEEL TABLE RECT      99.96
#
#
#
#
# 10 Least priced items
#
#
#        StockCode  UnitPrice                    Description
# 299983         B  -11062.06                Adjust bad debt
# 146982     16254       0.00                            NaN
# 433457     21352       0.00                          check
# 433458     84050       0.00                          check
# 433527    47503A       0.00                          check
# 290639     21246       0.00                            NaN
# 290583    84596L       0.00                            NaN
# 290582    47559B       0.00                            NaN
# 290581     23175       0.00                            NaN
# 131706     22173       0.00                            NaN
# 165565    85027L       0.00                            NaN
# 131705     21361       0.00                            NaN
# 30603      21479       0.00  WHITE SKULL HOT WATER BOTTLE
# 433687     21644       0.00                          check
# 433688     35968       0.00                          check
# 433689     21539       0.00                          check
# 433690     21700       0.00                          check
# 433692     82600       0.00                          check
# 433693    16207A       0.00                          check
# 433694     22848       0.00                          check

# %%
# storing different countries in the dataset for Question 4,5,6,7

country_df = retail_landing_df[['Country']].drop_duplicates()
country_list = list(country_df['Country'])

print(country_list)
# Out:
# ['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany', 'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal', 'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland', 'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria', 'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore', 'Lebanon', 'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA', 'European Community', 'Malta', 'RSA']

# %%
# Question 4,5 
# Top Purchase Items based on country 
for country in country_list:
    item_df = retail_landing_df[(retail_landing_df.Country == country)]
    top_10_items_quant_df = getTop10ByQuantity(item_df[['StockCode','Quantity','Description']],ascending=False).head(10)
    top_10_items_price_df = getTop10ByPrice(item_df[['StockCode','UnitPrice','Description']],ascending=False).head(10)
    bottom_10_items_quant_df = getTop10ByQuantity(item_df[['StockCode','Quantity','Description']]).head(10)
    bottom_10_items_price_df = getTop10ByPrice(item_df[['StockCode','UnitPrice','Description']]).head(10)
    print("Top 10 Items Purchased by customers in {0}".format(country))
    print(top_10_items_quant_df.to_string(index=False))
    print("\n")
    print("10 Items Least Purchased / Cancelled Items by customers in {0}".format(country))
    print(bottom_10_items_quant_df.to_string(index=False))
    print("\n")
    print("Top 10 Items By Price in {0}".format(country))
    print(top_10_items_price_df.to_string(index=False))
    print("\n")
    print("10 Least Priced Items / Cancelled Items in {0}".format(country))
    print(bottom_10_items_price_df.to_string(index=False))
    print("\n\n")
# Out:
# Top 10 Items Purchased by customers in United Kingdom
# StockCode  Quantity                          Description
#    23843     80995          PAPER CRAFT , LITTLE BIRDIE
#    23166     74215       MEDIUM CERAMIC TOP STORAGE JAR
#    84826     12540       ASSTD DESIGN 3D PAPER STICKERS
#    37413      5568                                  NaN
#    84077      4800    WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    22197      4300                 SMALL POPCORN HOLDER
#   85123A      4000                                    ?
#    22053      3906                EMPIRE DESIGN ROSETTE
#    18007      3186  ESSENTIAL BALM 3.5g TIN IN ENVELOPE
#    21108      3114   FAIRY CAKE FLANNEL ASSORTED COLOUR
#
#
# 10 Items Least Purchased / Cancelled Items by customers in United Kingdom
# StockCode  Quantity                          Description
#    23843    -80995          PAPER CRAFT , LITTLE BIRDIE
#    23166    -74215       MEDIUM CERAMIC TOP STORAGE JAR
#    23005     -9600         printing smudges/thrown away
#    23005     -9600         printing smudges/thrown away
#    84347     -9360  ROTATING SILVER ANGELS T-LIGHT HLDR
#    23003     -9058         Printing smudges/thrown away
#   72140F     -5368                           throw away
#   79323W     -4830               Unsaleable, destroyed.
#    16045     -3667                                  NaN
#    16259     -3167                                  NaN
#
#
# Top 10 Items By Price in United Kingdom
# StockCode  UnitPrice      Description
#         M   38970.00           Manual
# AMAZONFEE   17836.46       AMAZON FEE
# AMAZONFEE   16888.02       AMAZON FEE
# AMAZONFEE   16453.71       AMAZON FEE
# AMAZONFEE   13541.33       AMAZON FEE
# AMAZONFEE   13541.33       AMAZON FEE
# AMAZONFEE   13541.33       AMAZON FEE
# AMAZONFEE   13474.79       AMAZON FEE
# AMAZONFEE   11586.50       AMAZON FEE
#         B   11062.06  Adjust bad debt
#
#
# 10 Least Priced Items / Cancelled Items in United Kingdom
# StockCode  UnitPrice      Description
#        B  -11062.06  Adjust bad debt
#        B  -11062.06  Adjust bad debt
#    21637       0.00              NaN
#    84218       0.00              NaN
#    21160       0.00              NaN
#    22194       0.00              NaN
#    21171       0.00              NaN
#   35603B       0.00              NaN
#    20821       0.00              NaN
#    47502       0.00              NaN
#
#
#
# Top 10 Items Purchased by customers in France
# StockCode  Quantity                         Description
#    23084       912                  RABBIT NIGHT LIGHT
#    21381       576  MINI WOODEN HAPPY BIRTHDAY GARLAND
#    22610       360            PENS ASSORTED FUNNY FACE
#    22386       300             JUMBO BAG PINK POLKADOT
#    23203       300            JUMBO BAG VINTAGE DOILY
#    23084       288                  RABBIT NIGHT LIGHT
#    22959       250              WRAP CHRISTMAS VILLAGE
#    22959       250              WRAP CHRISTMAS VILLAGE
#    16218       240          CARTOON  PENCIL SHARPENERS
#    22609       216             PENS ASSORTED SPACEBALL
#
#
# 10 Items Least Purchased / Cancelled Items by customers in France
# StockCode  Quantity                          Description
#    22959      -250               WRAP CHRISTMAS VILLAGE
#    22922      -120     FRIDGE MAGNETS US DINER ASSORTED
#    22923      -120  FRIDGE MAGNETS LES ENFANTS ASSORTED
#    22924      -120        FRIDGE MAGNETS LA VIE EN ROSE
#    22818       -72               CARD CHRISTMAS VILLAGE
#    22398       -60           MAGNETS PACK OF 4 SWALLOWS
#    35970       -36            ZINC FOLKART SLEIGH BELLS
#    72586       -36    SET OF 6 HALLOWEEN GHOST T-LIGHTS
#    22705       -25                    WRAP GREEN PEARS
#    23232       -25          WRAP VINTAGE PETALS  DESIGN
#
#
# Top 10 Items By Price in France
# StockCode  UnitPrice Description
#        M    4161.06      Manual
#        M    4161.06      Manual
#        M    4161.06      Manual
#        M    1136.30      Manual
#        M    1136.30      Manual
#       C2     150.00    CARRIAGE
#     POST     145.00     POSTAGE
#     POST     145.00     POSTAGE
#     POST     145.00     POSTAGE
#     POST     134.00     POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in France
# StockCode  UnitPrice                      Description
#        M       0.00                           Manual
#    16218       0.06       CARTOON  PENCIL SHARPENERS
#    16218       0.06       CARTOON  PENCIL SHARPENERS
#    16219       0.06     HOUSE SHAPE PENCIL SHARPENER
#    16048       0.12  TEATIME ROUND PENCIL SHARPENER
#    16048       0.12  TEATIME ROUND PENCIL SHARPENER
#    20668       0.12  DISCO BALL CHRISTMAS DECORATION
#    21402       0.12                  RED  EGG  SPOON
#    21402       0.12                  RED  EGG  SPOON
#    21403       0.12                  BLUE EGG  SPOON
#
#
#
# Top 10 Items Purchased by customers in Australia
# StockCode  Quantity                Description
#    22492      1152    MINI PAINT SET VINTAGE
#    23084       960         RABBIT NIGHT LIGHT
#    21915       720     RED  HARMONICA IN BOX
#    15036       600  ASSORTED COLOURS SILK FAN
#    22492       576    MINI PAINT SET VINTAGE
#    21902       576     KEY FOB , FRONT  DOOR
#    21900       576             KEY FOB , SHED
#    21899       576    KEY FOB , GARAGE DESIGN
#    22492       576    MINI PAINT SET VINTAGE
#    22492       576    MINI PAINT SET VINTAGE
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Australia
# StockCode  Quantity                       Description
#    22738      -120         RIBBON REEL SNOWY VILLAGE
#    22990      -100        COTTON APRON PANTRY DESIGN
#    22969       -86      HOMEMADE JAM SCENTED CANDLES
#    22492       -36           MINI PAINT SET VINTAGE
#    84978       -36  HANGING HEART JAR T-LIGHT HOLDER
#    22697       -24   GREEN REGENCY TEACUP AND SAUCER
#    21198       -24      WHITE HEART CONFETTI IN TUBE
#    22087       -18          PAPER BUNTING WHITE LACE
#    22090       -12           PAPER BUNTING RETROSPOT
#    22232        -8         JIGSAW TOADSTOOLS 3 PIECE
#
#
# Top 10 Items By Price in Australia
# StockCode  UnitPrice                    Description
#     POST     350.00                        POSTAGE
#     POST     262.73                        POSTAGE
#    22848      14.95     BREAD BIN DINER STYLE PINK
#    22838      14.95  3 TIER CAKE TIN RED AND CREAM
#    22838      14.95  3 TIER CAKE TIN RED AND CREAM
#    23009      14.95    I LOVE LONDON BABY GIFT SET
#    22846      14.95     BREAD BIN DINER STYLE RED
#    22849      14.95     BREAD BIN DINER STYLE MINT
#    22503      12.75      CABIN BAG VINTAGE PAISLEY
#    22946      12.75   WOODEN ADVENT CALENDAR CREAM
#
#
# 10 Least Priced Items / Cancelled Items in Australia
# StockCode  UnitPrice                        Description
#    23234       0.00      BISCUIT TIN VINTAGE CHRISTMAS
#    22619       0.00          SET OF 6 SOLDIER SKITTLES
#    22385       0.00          JUMBO BAG SPACEBOY DESIGN
#    21084       0.19           SET/6 COLLAGE PAPER CUPS
#    22338       0.19      STAR DECORATION PAINTED ZINC
#    21981       0.25       PACK OF 12 WOODLAND TISSUES
#    21984       0.25   PACK OF 12 PINK PAISLEY TISSUES
#    22615       0.25  PACK OF 12 CIRCUS PARADE TISSUES
#    20984       0.29          12 PENCILS TALL TUBE POSY
#    23187       0.29   FRENCH STYLE STORAGE JAR BONBONS
#
#
#
# Top 10 Items Purchased by customers in Netherlands
# StockCode  Quantity                        Description
#    23084      2400                 RABBIT NIGHT LIGHT
#    22595      1728           GINGHAM HEART DECORATION
#    23084      1440                 RABBIT NIGHT LIGHT
#    21212      1440    PACK OF 72 RETROSPOT CAKE CASES
#    21212      1200    PACK OF 72 RETROSPOT CAKE CASES
#    22243       960  5 HOOK HANGER RED MAGIC TOADSTOOL
#    22629       640                SPACEBOY LUNCH BOX
#    22630       640               DOLLY GIRL LUNCH BOX
#    22492       576            MINI PAINT SET VINTAGE
#    22492       576            MINI PAINT SET VINTAGE
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Netherlands
# StockCode  Quantity                         Description
#        M      -480                              Manual
#    21787      -144               RAIN PONCHO RETROSPOT
#    22956      -144            36 FOIL HEART CAKE CASES
#    22291       -24      HANGING CHICK CREAM DECORATION
#   47503A       -12  ASS FLORAL PRINT MULTI SCREWDRIVER
#     POST        -3                             POSTAGE
#     POST        -1                             POSTAGE
#        D        -1                            Discount
#    23206         1              LUNCH BAG APPLE DESIGN
#    23480         1      MINI LIGHTS WOODLAND MUSHROOMS
# Top 10 Items By Price in Netherlands
# StockCode  UnitPrice                    Description
#        D     206.40                       Discount
#    22823     110.00  CHEST NATURAL WOOD 20 DRAWERS
#    22826      85.00  LOVE SEAT ANTIQUE WHITE METAL
#    22826      85.00  LOVE SEAT ANTIQUE WHITE METAL
#    22929      57.95         SCHOOL DESK AND CHAIR
#    23064      41.75         CINDERELLA CHANDELIER
#    22803      39.95       IVORY EMBROIDERED QUILT
#    22802      19.95       FAUX FUR CHOCOLATE THROW
#     POST      18.00                        POSTAGE
#     POST      18.00                        POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Netherlands
# StockCode  UnitPrice                          Description
#    21786       0.00                   POLKADOT RAIN HAT
#    23270       0.00     SET OF 2 CERAMIC PAINTED HEARTS
#    23268       0.00  SET OF 2 CERAMIC CHRISTMAS REINDEER
#    22955       0.00             36 FOIL STAR CAKE CASES
#    21088       0.19         SET/6 FRUIT SALAD PAPER CUPS
#    22544       0.19                 MINI JIGSAW SPACEBOY
#    22540       0.19           MINI JIGSAW CIRCUS PARADE
#    22343       0.19       PARTY PIZZA DISH RED RETROSPOT
#    22539       0.19               MINI JIGSAW DOLLY GIRL
#    84929       0.19   ASSTD FRUIT+FLOWERS FRIDGE MAGNETS
#
#
#
# Top 10 Items Purchased by customers in Germany
# StockCode  Quantity                      Description
#    15036       600        ASSORTED COLOURS SILK FAN
#    23379       432     PACK OF 12 RED APPLE TISSUES
#    15036       300        ASSORTED COLOURS SILK FAN
#    22585       288        PACK OF 6 BIRDY GIFT TAGS
#    84568       288  GIRLS ALPHABET IRON ON PATCHES
#    84598       288    BOYS ALPHABET IRON ON PATCHES
#    22893       288   MINI CAKE STAND T-LIGHT HOLDER
#    16045       200       POPART WOODEN PENCILS ASST
#    10135       200     COLOURING PENCILS BROWN TUBE
#    22629       192              SPACEBOY LUNCH BOX
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Germany
# StockCode  Quantity                          Description
#    84598      -288        BOYS ALPHABET IRON ON PATCHES
#    20977       -32             36 PENCILS TUBE WOODLAND
#    21498       -25                  RED RETROSPOT WRAP
#    22704       -25                     WRAP RED APPLES
#    21121       -24    SET/10 RED POLKADOT PARTY CANDLES
#    23307       -24  SET OF 60 PANTRY DESIGN CAKE CASES
#    22998       -24         TRAVEL CARD WALLET KEEP CALM
#    22242       -24        5 HOOK HANGER MAGIC TOADSTOOL
#    22423       -21             REGENCY CAKESTAND 3 TIER
#    22962       -17                JAM JAR WITH PINK LID
#
#
# Top 10 Items By Price in Germany
# StockCode  UnitPrice Description
#        M     599.50      Manual
#        M     599.50      Manual
#        M     549.34      Manual
#        M     549.34      Manual
#     POST     523.00     POSTAGE
#        M     424.06      Manual
#        M     424.06      Manual
#        M     389.68      Manual
#        M     389.68      Manual
#     POST     240.00     POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Germany
# StockCode  UnitPrice                   Description
#    22841       0.00  ROUND CAKE TIN VINTAGE GREEN
#        M       0.00                        Manual
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16045       0.04    POPART WOODEN PENCILS ASST
#    16218       0.06    CARTOON  PENCIL SHARPENERS
#
#
#
# Top 10 Items Purchased by customers in Norway
# StockCode  Quantity                          Description
#    16008       240  SMALL FOLDING SCISSOR(POINTED EDGE)
#    16008       240  SMALL FOLDING SCISSOR(POINTED EDGE)
#    22693       192   GROW A FLYTRAP OR SUNFLOWER IN TIN
#    22693       192   GROW A FLYTRAP OR SUNFLOWER IN TIN
#    72232       144              FENG SHUI PILLAR CANDLE
#    72232       144              FENG SHUI PILLAR CANDLE
#    84991       120          60 TEATIME FAIRY CAKE CASES
#    23307       120  SET OF 60 PANTRY DESIGN CAKE CASES
#    21213       120          PACK OF 72 SKULL CAKE CASES
#    21977       120   PACK OF 60 PINK PAISLEY CAKE CASES
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Norway
# StockCode  Quantity                          Description
#    84050       -12      PINK HEART SHAPE EGG FRYING PAN
#    37448       -12      CERAMIC CAKE DESIGN SPOTTED MUG
#    21791       -12   VINTAGE HEADS AND TAILS CARD GAME
#    21914       -12               BLUE HARMONICA IN BOX
#    22645       -12  CERAMIC HEART FAIRY CAKE MONEY BANK
#    23198       -10       PANTRY MAGNETIC  SHOPPING LIST
#    22701        -6                        PINK DOG BOWL
#    22413        -6      METAL SIGN TAKE IT OR LEAVE IT
#    22784        -3                LANTERN CREAM GAZEBO
#    23243        -2  SET OF TEA COFFEE SUGAR TINS PANTRY
#
#
# Top 10 Items By Price in Norway
# StockCode  UnitPrice             Description
#     POST     700.00                 POSTAGE
#        M     376.50                  Manual
#        M     376.50                  Manual
#        M     280.05                  Manual
#        M     280.05                  Manual
#        M     183.75                  Manual
#        M     183.75                  Manual
#    22929      65.00  SCHOOL DESK AND CHAIR
#     POST      40.00                 POSTAGE
#     POST      40.00                 POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Norway
# StockCode  UnitPrice                          Description
#    23407       0.00       SET OF 2 TRAYS HOME SWEET HOME
#    16219       0.06         HOUSE SHAPE PENCIL SHARPENER
#    17038       0.10       PORCELAIN BUDAH INCENSE HOLDER
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    15034       0.14          PAPER POCKET TRAVELING FAN
#    15034       0.14          PAPER POCKET TRAVELING FAN
#    72232       0.19              FENG SHUI PILLAR CANDLE
#
#
#
# Top 10 Items Purchased by customers in EIRE
# StockCode  Quantity                        Description
#   17084R      1440              ASSORTED INCENSE PACK
#    84212       960      ASSORTED FLOWER COLOUR "LEIS"
#    22266       640    EASTER DECORATION HANGING BUNNY
#    22197       500                     POPCORN HOLDER
#    22950       432       36 DOILIES VINTAGE CHRISTMAS
#    22151       432          PLACE SETTING WHITE HEART
#    22666       408    RECIPE BOX PANTRY YELLOW DESIGN
#    22667       408              RECIPE BOX RETROSPOT
#    22197       400               SMALL POPCORN HOLDER
#    21292       384  SMALL STRIPES CHOCOLATE GIFT BAG
#
#
# 10 Items Least Purchased / Cancelled Items by customers in EIRE
# StockCode  Quantity                          Description
#    22950      -288         36 DOILIES VINTAGE CHRISTMAS
#    22952      -240      60 CAKE CASES VINTAGE CHRISTMAS
#    23157      -240           SET OF 6 NATIVITY MAGNETS
#    22910      -200    PAPER CHAIN KIT VINTAGE CHRISTMAS
#    22630      -192                 DOLLY GIRL LUNCH BOX
#    22909      -192  SET OF 20 VINTAGE CHRISTMAS NAPKINS
#    22945      -144       CHRISTMAS METAL TAGS ASSORTED
#    22699      -120     ROSES REGENCY TEACUP AND SAUCER
#    22086      -120      PAPER CHAIN KIT 50'S CHRISTMAS
#    22363      -120                 GLASS JAR MARMALADE
#
#
# Top 10 Items By Price in EIRE
# StockCode  UnitPrice Description
#        M    1917.00      Manual
#        M    1917.00      Manual
#        M    1687.17      Manual
#        M    1687.17      Manual
#        M    1687.17      Manual
#        M    1687.17      Manual
#        M    1216.12      Manual
#        M    1216.12      Manual
#        M    1121.18      Manual
#        M     542.20      Manual
#
#
# 10 Least Priced Items / Cancelled Items in EIRE
# StockCode  UnitPrice                    Description
#    23157       0.00     SET OF 6 NATIVITY MAGNETS
#    23196       0.00  VINTAGE LEAF MAGNETIC NOTEPAD
#    22624       0.00           IVORY KITCHEN SCALES
#    22423       0.00       REGENCY CAKESTAND 3 TIER
#    16045       0.04     POPART WOODEN PENCILS ASST
#    16045       0.04     POPART WOODEN PENCILS ASST
#    16045       0.04     POPART WOODEN PENCILS ASST
#    16045       0.04     POPART WOODEN PENCILS ASST
#    16218       0.06     CARTOON  PENCIL SHARPENERS
#    16216       0.06  LETTER SHAPE PENCIL SHARPENER
#
#
#
# Top 10 Items Purchased by customers in Switzerland
# StockCode  Quantity                          Description
#    84568       288      GIRLS ALPHABET IRON ON PATCHES
#    22857       144            ASSORTED EASTER GIFT TAGS
#    21680       144                   WOODLAND  STICKERS
#    21976       120       PACK OF 60 MUSHROOM CAKE CASES
#    22417       120       PACK OF 60 SPACEBOY CAKE CASES
#    84012       120  MAGIC SHEEP WOOL GROWING FROM PAPER
#    23432       120        PRETTY HANGING QUILTED HEARTS
#    21212       120      PACK OF 72 RETROSPOT CAKE CASES
#    21212       120      PACK OF 72 RETROSPOT CAKE CASES
#    22858       108                  EASTER TIN KEEPSAKE
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Switzerland
# StockCode  Quantity                          Description
#    84012      -120  MAGIC SHEEP WOOL GROWING FROM PAPER
#    23199      -100                     JUMBO BAG APPLES
#    23196        -8        VINTAGE LEAF MAGNETIC NOTEPAD
#    23198        -7       PANTRY MAGNETIC  SHOPPING LIST
#    22636        -6   CHILDS BREAKFAST SET CIRCUS PARADE
#    22699        -6     ROSES REGENCY TEACUP AND SAUCER
#    23236        -5           STORAGE TIN VINTAGE DOILY
#   47594A        -5              CAROUSEL DESIGN WASHBAG
#    23256        -4          CHILDRENS CUTLERY SPACEBOY
#    23029        -4      DRAWER KNOB CRACKLE GLAZE GREEN
#
#
# Top 10 Items By Price in Switzerland
# StockCode  UnitPrice Description
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#     POST       40.0     POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Switzerland
# StockCode  UnitPrice                          Description
#    22636       0.00   CHILDS BREAKFAST SET CIRCUS PARADE
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    18007       0.18  ESSENTIAL BALM 3.5g TIN IN ENVELOPE
#    22336       0.19        DOVE DECORATION PAINTED ZINC
#    21088       0.19         SET/6 FRUIT SALAD PAPER CUPS
#    22339       0.19         CHRISTMAS TREE PAINTED ZINC
#    21883       0.19                     STARS GIFT TAPE
#    22338       0.19        STAR DECORATION PAINTED ZINC
#    21881       0.19                       CUTE CATS TAPE
# Top 10 Items Purchased by customers in Spain
# StockCode  Quantity                         Description
#   84997D       360     CHILDRENS CUTLERY POLKADOT PINK
#   84997C       360   BLUE 3 PIECE POLKADOT CUTLERY SET
#   84997C       360     CHILDRENS CUTLERY POLKADOT BLUE
#   84997D       360     CHILDRENS CUTLERY POLKADOT PINK
#   84997D       360   PINK 3 PIECE POLKADOT CUTLERY SET
#   84997C       288     CHILDRENS CUTLERY POLKADOT BLUE
#   72802C       288   VANILLA SCENT CANDLE JEWELLED BOX
#   72802B       200  OCEAN SCENT CANDLE IN JEWELLED BOX
#    20728       200                 LUNCH BAG CARS BLUE
#    22384       150             LUNCH BAG PINK POLKADOT
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Spain
# StockCode  Quantity                          Description
#   72802C      -288    VANILLA SCENT CANDLE JEWELLED BOX
#   72802B      -200   OCEAN SCENT CANDLE IN JEWELLED BOX
#   82494L       -72          WOODEN FRAME ANTIQUE WHITE
#    82482       -72    WOODEN PICTURE FRAME WHITE FINISH
#    23055       -48      IVORY CHANDELIER T-LIGHT HOLDER
#    23072       -48  MARIE ANTOINETTE TRINKET BOX SILVER
#    23071       -48    MARIE ANTOINETTE TRINKET BOX GOLD
#    23056       -48    FLOWERS CHANDELIER T-LIGHT HOLDER
#    23057       -48     BEADED CHANDELIER T-LIGHT HOLDER
#    82483       -32   WOOD 2 DRAWER CABINET WHITE FINISH
#
#
# Top 10 Items By Price in Spain
# StockCode  UnitPrice                  Description
#        M    1715.85                       Manual
#        M    1126.00                       Manual
#    22929      65.00       SCHOOL DESK AND CHAIR
#    23064      41.75       CINDERELLA CHANDELIER
#    23064      41.75       CINDERELLA CHANDELIER
#    22504      29.95  CABIN BAG VINTAGE RETROSPOT
#    22504      29.95  CABIN BAG VINTAGE RETROSPOT
#     POST      28.00                      POSTAGE
#     POST      28.00                      POSTAGE
#     POST      28.00                      POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Spain
# StockCode  UnitPrice                       Description
#    22960       0.00          JAM MAKING SET WITH JARS
#    21403       0.12                   BLUE EGG  SPOON
#    21402       0.12                   RED  EGG  SPOON
#    85204       0.12      HANGING WOOD AND FELT FLOWER
#    15034       0.14       PAPER POCKET TRAVELING FAN
#    21084       0.19          SET/6 COLLAGE PAPER CUPS
#   84251B       0.19      GREETING CARD, STICKY GORDON
#   84251C       0.19       GREETING CARD, TWO SISTERS.
#    22161       0.19  HEART DECORATION RUSTIC HANGING
#    22043       0.19      CHRISTMAS CARD SCREEN PRINT
#
#
#
# Top 10 Items Purchased by customers in Poland
# StockCode  Quantity                          Description
#    21232        72       STRAWBERRY CERAMIC TRINKET BOX
#    37448        48      CERAMIC CAKE DESIGN SPOTTED MUG
#    35953        48   FOLKART STAR CHRISTMAS DECORATIONS
#    23084        48                   RABBIT NIGHT LIGHT
#    85094        48         CANDY SPOT EGG WARMER RABBIT
#    21824        48  PAINTED METAL STAR WITH HOLLY BELLS
#    22065        48       CHRISTMAS PUDDING TRINKET POT
#    22059        48        CERAMIC STRAWBERRY DESIGN MUG
#    22961        48               JAM MAKING SET PRINTED
#    37448        48      CERAMIC CAKE DESIGN SPOTTED MUG
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Poland
# StockCode  Quantity                        Description
#    37448        -6    CERAMIC CAKE DESIGN SPOTTED MUG
#    23108        -4         SET OF 10 LED DOLLY LIGHTS
#    37447        -4  CERAMIC CAKE DESIGN SPOTTED PLATE
#    22796        -4      PHOTO FRAME 3 CLASSIC HANGING
#    22666        -3    RECIPE BOX PANTRY YELLOW DESIGN
#    23423        -2   PANTRY 3 HOOK ROLLING PIN HANGER
#    21929        -2     JUMBO BAG PINK VINTAGE PAISLEY
#    22993        -2       SET OF 4 PANTRY JELLY MOULDS
#    22666        -2    RECIPE BOX PANTRY YELLOW DESIGN
#    37450        -1  CERAMIC CAKE BOWL + HANGING CAKES
#
#
# Top 10 Items By Price in Poland
# StockCode  UnitPrice                          Description
#     POST      40.00                              POSTAGE
#     POST      40.00                              POSTAGE
#     POST      40.00                              POSTAGE
#     POST      40.00                              POSTAGE
#     POST      40.00                              POSTAGE
#   84078A      39.95     SET/4 WHITE RETRO STORAGE CUBES
#    22761      24.95           CHEST 7 DRAWER MA CAMPAGNE
#    21277      21.95  FRENCH STYLE EMBOSSED HEART CABINET
#    22847      16.95          BREAD BIN DINER STYLE IVORY
#    22762      14.95        CUPBOARD 3 DRAWER MA CAMPAGNE
#
#
# 10 Least Priced Items / Cancelled Items in Poland
# StockCode  UnitPrice                          Description
#    85094       0.19         CANDY SPOT EGG WARMER RABBIT
#    35953       0.39   FOLKART STAR CHRISTMAS DECORATIONS
#    22340       0.39           NOEL GARLAND PAINTED ZINC
#    22065       0.39       CHRISTMAS PUDDING TRINKET POT
#    22094       0.39             RED RETROSPOT TISSUE BOX
#    22092       0.39              BLUE PAISLEY TISSUE BOX
#    21824       0.39  PAINTED METAL STAR WITH HOLLY BELLS
#    20803       0.42         SMALL PINK GLASS SUNDAE DISH
#    16014       0.42          SMALL CHINESE STYLE SCISSOR
#    16014       0.42          SMALL CHINESE STYLE SCISSOR
#
#
#
# Top 10 Items Purchased by customers in Portugal
# StockCode  Quantity                          Description
#    22922       120     FRIDGE MAGNETS US DINER ASSORTED
#    84992       120       72 SWEETHEART FAIRY CAKE CASES
#    84991       120          60 TEATIME FAIRY CAKE CASES
#    22924       120        FRIDGE MAGNETS LA VIE EN ROSE
#    22923       120  FRIDGE MAGNETS LES ENFANTS ASSORTED
#    22740        96                         POLKADOT PEN
#    22857        72            ASSORTED EASTER GIFT TAGS
#    21231        72       SWEETHEART CERAMIC TRINKET BOX
#    22492        72              MINI PAINT SET VINTAGE
#    22435        60       SET OF 9 HEART SHAPED BALLOONS
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Portugal
# StockCode  Quantity                         Description
#    21892       -12  TRADITIONAL WOODEN CATCH CUP GAME
#    22960       -12            JAM MAKING SET WITH JARS
#    21791       -12  VINTAGE HEADS AND TAILS CARD GAME
#    21891       -12    TRADITIONAL WOODEN SKIPPING ROPE
#    21643       -12        ASSORTED TUTTI FRUTTI MIRROR
#   85099B        -3             JUMBO BAG RED RETROSPOT
#    22623        -3       BOX OF VINTAGE JIGSAW BLOCKS
#    22667        -2               RECIPE BOX RETROSPOT
#        M        -1                              Manual
#    23245        -1          SET OF 3 REGENCY CAKE TINS
#
#
# Top 10 Items By Price in Portugal
# StockCode  UnitPrice Description
#        M    1241.98      Manual
#        M    1241.98      Manual
#        M    1241.98      Manual
#        M    1241.98      Manual
#        M     557.72      Manual
#        M     557.72      Manual
#        M     557.72      Manual
#        M     557.72      Manual
#        M     339.02      Manual
#        M     339.02      Manual
#
#
# 10 Least Priced Items / Cancelled Items in Portugal
# StockCode  UnitPrice                          Description
#    16048       0.12      TEATIME ROUND PENCIL SHARPENER
#   47518F       0.12          ICON PLACEMAT POP ART ELVIS
#    16008       0.12  SMALL FOLDING SCISSOR(POINTED EDGE)
#    22338       0.19        STAR DECORATION PAINTED ZINC
#    22339       0.19         CHRISTMAS TREE PAINTED ZINC
#    22610       0.21             PENS ASSORTED FUNNY FACE
#    22577       0.29  WOODEN HEART CHRISTMAS SCANDINAVIAN
#    21980       0.29    PACK OF 12 RED RETROSPOT TISSUES
#    22578       0.29   WOODEN STAR CHRISTMAS SCANDINAVIAN
#    22579       0.29   WOODEN TREE CHRISTMAS SCANDINAVIAN
#
#
#
# Top 10 Items Purchased by customers in Italy
# StockCode  Quantity                  Description
#    23445       200            ICE CREAM BUBBLES
#   51014A       144         FEATHER PEN,HOT PINK
#    22197       100               POPCORN HOLDER
#   47593B        96        SCOTTIE DOGS BABY BIB
#   51014C        96       FEATHER PEN,COAL BLACK
#   51014A        96         FEATHER PEN,HOT PINK
#    21306        72   SET/4 DAISY MIRROR MAGNETS
#   51014C        72       FEATHER PEN,COAL BLACK
#    21700        72  BIG DOUGHNUT FRIDGE MAGNETS
#   51014L        72       FEATHER PEN,LIGHT PINK
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Italy
# StockCode  Quantity                         Description
#    21987       -12          PACK OF 6 SKULL PAPER CUPS
#    20980        -9                36 PENCILS TUBE POSY
#    22099        -9           CARAVAN SQUARE TISSUE BOX
#    22120        -9       WELCOME  WOODEN BLOCK LETTERS
#    22960        -6            JAM MAKING SET WITH JARS
#    22844        -3    VINTAGE CREAM DOG FOOD CONTAINER
#    22847        -3         BREAD BIN DINER STYLE IVORY
#    22352        -3   LUNCH BOX WITH CUTLERY RETROSPOT
#   85123A        -3  WHITE HANGING HEART T-LIGHT HOLDER
#    22720        -3   SET OF 3 CAKE TINS PANTRY DESIGN
#
#
# Top 10 Items By Price in Italy
# StockCode  UnitPrice                       Description
#     POST     300.00                           POSTAGE
#     POST      40.00                           POSTAGE
#     POST      40.00                           POSTAGE
#     POST      40.00                           POSTAGE
#     POST      40.00                           POSTAGE
#     POST      40.00                           POSTAGE
#   84078A      39.95  SET/4 WHITE RETRO STORAGE CUBES
#     POST      35.00                           POSTAGE
#     POST      28.00                           POSTAGE
#     POST      28.00                           POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Italy
# StockCode  UnitPrice                        Description
#    16048       0.12    TEATIME ROUND PENCIL SHARPENER
#    21306       0.29         SET/4 DAISY MIRROR MAGNETS
#    21980       0.29  PACK OF 12 RED RETROSPOT TISSUES
#    21986       0.29   PACK OF 12 PINK POLKADOT TISSUES
#    21981       0.39       PACK OF 12 WOODLAND TISSUES
#   51014A       0.39               FEATHER PEN,HOT PINK
#   51014C       0.39             FEATHER PEN,COAL BLACK
#   51014L       0.39             FEATHER PEN,LIGHT PINK
#    21985       0.39  PACK OF 12 HEARTS DESIGN TISSUES
#    21967       0.39           PACK OF 12 SKULL TISSUES
# Top 10 Items Purchased by customers in Belgium
# StockCode  Quantity                         Description
#   84536B       272        FAIRY CAKES NOTEBOOK A7 SIZE
#    23310       180             BUBBLEGUM RING ASSORTED
#    22489       144      PACK OF 12 TRADITIONAL CRAYONS
#    21212       120     PACK OF 72 RETROSPOT CAKE CASES
#    21977       120  PACK OF 60 PINK PAISLEY CAKE CASES
#    22417       120      PACK OF 60 SPACEBOY CAKE CASES
#    22492       108             MINI PAINT SET VINTAGE
#    16045       100          POPART WOODEN PENCILS ASST
#    20724       100         RED RETROSPOT CHARLOTTE BAG
#    22355       100           CHARLOTTE BAG SUKI DESIGN
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Belgium
# StockCode  Quantity                          Description
#    20981       -12        12 PENCILS TALL TUBE WOODLAND
#    23660       -12                   HENRIETTA HEN MUG
#    22659        -6              LUNCH BOX I LOVE LONDON
#    21318        -6            GLASS CHALICE BLUE SMALL
#    22845        -3     VINTAGE CREAM CAT FOOD CONTAINER
#   85232A        -3         SET/3 POLKADOT STACKING TINS
#    22943        -3  CHRISTMAS LIGHTS 10 VINTAGE BAUBLES
#    21218        -3               RED SPOTTY BISCUIT TIN
#    22628        -3     PICNIC BOXES SET OF 3 RETROSPOT
#    72741        -2                GRAND CHOCOLATECANDLE
#
#
# Top 10 Items By Price in Belgium
# StockCode  UnitPrice                  Description
#    84816      39.95  DANISH ROSE BEDSIDE CABINET
#    22504      29.95  CABIN BAG VINTAGE RETROSPOT
#    22504      29.95  CABIN BAG VINTAGE RETROSPOT
#    22504      24.95  CABIN BAG VINTAGE RETROSPOT
#    23462      19.95     ROCOCO WALL MIRROR WHITE
#    23462      19.95     ROCOCO WALL MIRROR WHITE
#     POST      18.00                      POSTAGE
#     POST      18.00                      POSTAGE
#     POST      18.00                      POSTAGE
#     POST      18.00                      POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Belgium
# StockCode  UnitPrice                          Description
#    16045       0.12           POPART WOODEN PENCILS ASST
#    16048       0.12      TEATIME ROUND PENCIL SHARPENER
#   47518F       0.12          ICON PLACEMAT POP ART ELVIS
#    20668       0.12      DISCO BALL CHRISTMAS DECORATION
#    16048       0.12      TEATIME ROUND PENCIL SHARPENER
#    18007       0.18  ESSENTIAL BALM 3.5g TIN IN ENVELOPE
#    21879       0.19                     HEARTS GIFT TAPE
#    21880       0.19                   RED RETROSPOT TAPE
#    21084       0.19             SET/6 COLLAGE PAPER CUPS
#    16238       0.21            PARTY TIME PENCIL ERASERS
#
#
#
# Top 10 Items Purchased by customers in Lithuania
# StockCode  Quantity                         Description
#    22271        48                FELTCRAFT DOLL ROSIE
#    22306        36  SILVER MUG BONE CHINA TREE OF LIFE
#    21915        36              RED  HARMONICA IN BOX
#    22307        36    GOLD MUG BONE CHINA TREE OF LIFE
#    21914        36              BLUE HARMONICA IN BOX
#    22145        30     CHRISTMAS CRAFT HEART STOCKING
#    22568        24               FELTCRAFT CUSHION OWL
#   85206A        24        CREAM FELT EASTER EGG BASKET
#    22021        24         BLUE FELT EASTER EGG BASKET
#    22554        24    PLASTERS IN TIN WOODLAND ANIMALS
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Lithuania
# StockCode  Quantity                        Description
#    20686         6  DOLLY MIXTURE CHILDREN'S UMBRELLA
#    20682         6   RED RETROSPOT CHILDRENS UMBRELLA
#    20681         6   PINK POLKADOT CHILDRENS UMBRELLA
#    22569         8        FELTCRAFT CUSHION BUTTERFLY
#    21429         8     RED GINGHAM ROSE JEWELLERY BOX
#    22409        12          MONEY BOX BISCUITS DESIGN
#    22751        12     FELTCRAFT PRINCESS OLIVIA DOLL
#    21915        12             RED  HARMONICA IN BOX
#    22553        12             PLASTERS IN TIN SKULLS
#    22273        12               FELTCRAFT DOLL MOLLY
#
#
# Top 10 Items By Price in Lithuania
# StockCode  UnitPrice                         Description
#  15056BL       5.95             EDWARDIAN PARASOL BLACK
#   15056N       5.95           EDWARDIAN PARASOL NATURAL
#    20679       5.95               EDWARDIAN PARASOL RED
#    22940       4.25           FELTCRAFT CHRISTMAS FAIRY
#    22751       3.75      FELTCRAFT PRINCESS OLIVIA DOLL
#    20967       3.75  GREY FLORAL FELTCRAFT SHOULDER BAG
#    22750       3.75        FELTCRAFT PRINCESS LOLA DOLL
#    22569       3.75         FELTCRAFT CUSHION BUTTERFLY
#    20967       3.75  GREY FLORAL FELTCRAFT SHOULDER BAG
#    22569       3.75         FELTCRAFT CUSHION BUTTERFLY
#
#
# 10 Least Priced Items / Cancelled Items in Lithuania
# StockCode  UnitPrice                       Description
#    22409       1.25         MONEY BOX BISCUITS DESIGN
#    21915       1.25            RED  HARMONICA IN BOX
#    21915       1.25            RED  HARMONICA IN BOX
#    21914       1.25            BLUE HARMONICA IN BOX
#    22021       1.65       BLUE FELT EASTER EGG BASKET
#   85206A       1.65      CREAM FELT EASTER EGG BASKET
#    21429       1.65    RED GINGHAM ROSE JEWELLERY BOX
#   85114B       1.65   IVORY ENCHANTED FOREST PLACEMAT
#    22553       1.65            PLASTERS IN TIN SKULLS
#    22554       1.65  PLASTERS IN TIN WOODLAND ANIMALS
#
#
#
# Top 10 Items Purchased by customers in Japan
# StockCode  Quantity                          Description
#    23084      2040                   RABBIT NIGHT LIGHT
#    22328      1488   ROUND SNACK BOXES SET OF 4 FRUITS
#    23084       960                   RABBIT NIGHT LIGHT
#    22489       576       PACK OF 12 TRADITIONAL CRAYONS
#    21918       576     SET 12 KIDS COLOUR  CHALK STICKS
#    22531       576  MAGIC DRAWING SLATE CIRCUS PARADE
#    22533       576     MAGIC DRAWING SLATE BAKE A CAKE
#    22534       576        MAGIC DRAWING SLATE SPACEBOY
#    22492       576              MINI PAINT SET VINTAGE
#    22536       576           MAGIC DRAWING SLATE PURDEY
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Japan
# StockCode  Quantity                          Description
#    22328      -624   ROUND SNACK BOXES SET OF 4 FRUITS
#    22088       -40          PAPER BUNTING COLOURED LACE
#    22466       -17       FAIRY TALE COTTAGE NIGHT LIGHT
#    20979       -16        36 PENCILS TUBE RED RETROSPOT
#    23480       -15       MINI LIGHTS WOODLAND MUSHROOMS
#    22957       -12  SET 3 PAPER VINTAGE CHICK PAPER EGG
#    21218       -10               RED SPOTTY BISCUIT TIN
#    22364        -9         GLASS JAR DIGESTIVE BISCUITS
#    23084        -7                   RABBIT NIGHT LIGHT
#    23176        -4               ABC TREASURE BOOK BOX
#
#
# Top 10 Items By Price in Japan
# StockCode  UnitPrice                    Description
#        M      45.57                         Manual
#        M      17.55                         Manual
#        M      16.05                         Manual
#    23009      14.95    I LOVE LONDON BABY GIFT SET
#    22968       9.95     ROSE COTTAGE KEEPSAKE BOX
#    21217       8.95  RED RETROSPOT ROUND CAKE TINS
#    21054       8.95           NURSE'S BAG SOFT TOY
#    21217       8.95  RED RETROSPOT ROUND CAKE TINS
#    21217       8.95  RED RETROSPOT ROUND CAKE TINS
#    21056       7.95          DOCTOR'S BAG SOFT TOY
#
#
# 10 Least Priced Items / Cancelled Items in Japan
# StockCode  UnitPrice                        Description
#    84077       0.21  WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    22616       0.29         PACK OF 12 LONDON TISSUES
#    21980       0.29  PACK OF 12 RED RETROSPOT TISSUES
#    21980       0.29  PACK OF 12 RED RETROSPOT TISSUES
#    22615       0.29  PACK OF 12 CIRCUS PARADE TISSUES
#    22616       0.29         PACK OF 12 LONDON TISSUES
#    84077       0.29  WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    22025       0.36        RING OF ROSES BIRTHDAY CARD
#    22028       0.36       PENNY FARTHING BIRTHDAY CARD
#    22718       0.36                 CARD CAT AND TREE
#
#
#
# Top 10 Items Purchased by customers in Iceland
# StockCode  Quantity                      Description
#    23076       240       ICE CREAM SUNDAE LIP GLOSS
#    23084        48               RABBIT NIGHT LIGHT
#    22492        36          MINI PAINT SET VINTAGE
#    17021        36           NAMASTE SWAGAT INCENSE
#    22492        36          MINI PAINT SET VINTAGE
#   84558A        36     3D DOG PICTURE PLAYING CARDS
#   84558A        36     3D DOG PICTURE PLAYING CARDS
#    22492        36          MINI PAINT SET VINTAGE
#   85167B        30  BLACK GRAND BAROQUE PHOTO FRAME
#    21731        24    RED TOADSTOOL LED NIGHT LIGHT
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Iceland
# StockCode  Quantity                        Description
#    23173         2              REGENCY TEAPOT ROSES
#    23173         2              REGENCY TEAPOT ROSES
#   85232D         3      SET/3 DECOUPAGE STACKING TINS
#    22423         3           REGENCY CAKESTAND 3 TIER
#    22423         3           REGENCY CAKESTAND 3 TIER
#    22423         3           REGENCY CAKESTAND 3 TIER
#    22375         4  AIRLINE BAG VINTAGE JET SET BROWN
#    22725         4     ALARM CLOCK BAKELIKE CHOCOLATE
#    22376         4  AIRLINE BAG VINTAGE JET SET WHITE
#    22726         4         ALARM CLOCK BAKELIKE GREEN
#
#
# Top 10 Items By Price in Iceland
# StockCode  UnitPrice                     Description
#    22423      12.75        REGENCY CAKESTAND 3 TIER
#    22423      12.75        REGENCY CAKESTAND 3 TIER
#    22423      12.75        REGENCY CAKESTAND 3 TIER
#    22423      12.75        REGENCY CAKESTAND 3 TIER
#    23173       9.95           REGENCY TEAPOT ROSES
#    23173       9.95           REGENCY TEAPOT ROSES
#    23316       8.15            RED REFECTORY CLOCK
#    21064       5.95           BOOM BOX SPEAKER BOYS
#   47567B       5.95          TEA TIME KITCHEN APRON
#    20782       5.49  CAMOUFLAGE EAR MUFF HEADPHONES
#
#
# 10 Least Priced Items / Cancelled Items in Iceland
# StockCode  UnitPrice                          Description
#    16008       0.25  SMALL FOLDING SCISSOR(POINTED EDGE)
#    17021       0.30               NAMASTE SWAGAT INCENSE
#    23506       0.42         MINI PLAYING CARDS SPACEBOY
#    22134       0.42           MINI LADLE LOVE HEART RED
#    23508       0.42       MINI PLAYING CARDS DOLLY GIRL
#    23506       0.42         MINI PLAYING CARDS SPACEBOY
#    23508       0.42       MINI PLAYING CARDS DOLLY GIRL
#    22417       0.55       PACK OF 60 SPACEBOY CAKE CASES
#    21976       0.55       PACK OF 60 MUSHROOM CAKE CASES
#    84991       0.55          60 TEATIME FAIRY CAKE CASES
#
#
#
# Top 10 Items Purchased by customers in Channel Islands
# StockCode  Quantity                         Description
#    21785       407                        RAIN PONCHO
#    22386       200             JUMBO BAG PINK POLKADOT
#   85099C       200      JUMBO  BAG BAROQUE BLACK WHITE
#   85099B       200             JUMBO BAG RED RETROSPOT
#    23199       200                    JUMBO BAG APPLES
#    22720        96   SET OF 3 CAKE TINS PANTRY DESIGN
#    22741        96                      FUNKY DIVA PEN
#   85123A        72  WHITE HANGING HEART T-LIGHT HOLDER
#    22747        60          POPPY'S PLAYHOUSE BATHROOM
#    22748        60           POPPY'S PLAYHOUSE KITCHEN
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Channel Islands
# StockCode  Quantity                          Description
#    22169        -2     FAMILY ALBUM WHITE PICTURE FRAME
#    22170        -2   PICTURE FRAME WOOD TRIPLE PORTRAIT
#    21533        -1             RETROSPOT LARGE MILK JUG
#    23486        -1             ANTIQUE HEART SHELF UNIT
#    20914        -1  SET/5 RED RETROSPOT LID GLASS BOWLS
#    23092        -1      LARGE ANTIQUE WHITE PHOTO FRAME
#    21216        -1     SET 3 RETROSPOT TEA,COFFEE,SUGAR
#    22637        -1                PIGGY BANK RETROSPOT
#    21314        -1        SMALL GLASS HEART TRINKET POT
#        M        -1                               Manual
#
#
# Top 10 Items By Price in Channel Islands
# StockCode  UnitPrice                       Description
#        M     293.00                            Manual
#        M     293.00                            Manual
#       C2      50.00                          CARRIAGE
#       C2      50.00                          CARRIAGE
#       C2      50.00                          CARRIAGE
#    22782      24.95     SET 3 WICKER STORAGE BASKETS
#    22783      19.95  SET 3 WICKER OVAL BASKETS W LIDS
#    22509      16.95      SEWING BOX RETROSPOT DESIGN
#    23008      16.95          DOLLY GIRL BABY GIFT SET
#    23007      16.95            SPACEBOY BABY GIFT SET
#
#
# 10 Least Priced Items / Cancelled Items in Channel Islands
# StockCode  UnitPrice                        Description
#    85078       0.19  SCANDINAVIAN 3 HEARTS NAPKIN RING
#    21967       0.29           PACK OF 12 SKULL TISSUES
#    21698       0.39         MOCK LOBSTER FRIDGE MAGNET
#    21500       0.42                PINK POLKADOT WRAP
#    21916       0.42    SET 12 RETRO WHITE CHALK STICKS
#    23232       0.42           WRAP VINTAGE LEAF DESIGN
#    23546       0.42                 WRAP PAISLEY PARK
#    21917       0.42    SET 12 KIDS  WHITE CHALK STICKS
#    22985       0.42       WRAP, BILLBOARD FONTS DESIGN
#    21498       0.42                RED RETROSPOT WRAP
#
#
#
# Top 10 Items Purchased by customers in Denmark
# StockCode  Quantity                         Description
#    23295       256    SET OF 12 MINI LOAF BAKING CASES
#    23296       256      SET OF 6 TEA TIME BAKING CASES
#    21915       240              RED  HARMONICA IN BOX
#    22693       144  GROW A FLYTRAP OR SUNFLOWER IN TIN
#    22467       144                   GUMBALL COAT RACK
#    22951       120     60 CAKE CASES DOLLY GIRL DESIGN
#    22383       100              LUNCH BAG SUKI DESIGN
#    23201       100                  JUMBO BAG ALPHABET
#    20713       100                      JUMBO BAG OWLS
#    22865        96              HAND WARMER OWL DESIGN
# 10 Items Least Purchased / Cancelled Items by customers in Denmark
# StockCode  Quantity                      Description
#   16169E       -25             WRAP 50'S  CHRISTMAS
#    23511        -5   EMBROIDERED RIBBON REEL EMILY
#    22848        -4       BREAD BIN DINER STYLE PINK
#    22846        -4       BREAD BIN DINER STYLE RED
#    21731        -3    RED TOADSTOOL LED NIGHT LIGHT
#    22961        -2           JAM MAKING SET PRINTED
#    22666        -2  RECIPE BOX PANTRY YELLOW DESIGN
#    22849        -1       BREAD BIN DINER STYLE MINT
#     POST        -1                          POSTAGE
#     POST         1                          POSTAGE
#
#
# Top 10 Items By Price in Denmark
# StockCode  UnitPrice Description
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#     POST       18.0     POSTAGE
#
#
# 10 Least Priced Items / Cancelled Items in Denmark
# StockCode  UnitPrice                        Description
#    16237       0.21               SLEEPING CAT ERASERS
#    84077       0.29  WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    84077       0.29  WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    21982       0.29           PACK OF 12 SUKI TISSUES
#    23186       0.29     FRENCH STYLE STORAGE JAR CAFE
#    84077       0.29  WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    21967       0.39           PACK OF 12 SKULL TISSUES
#    22615       0.39  PACK OF 12 CIRCUS PARADE TISSUES
#    23378       0.39  PACK OF 12 50'S CHRISTMAS TISSUES
#    23377       0.39      PACK OF 12 DOLLY GIRL TISSUES
#
#
#
# Top 10 Items Purchased by customers in Cyprus
# StockCode  Quantity                          Description
#    84598       288        BOYS ALPHABET IRON ON PATCHES
#    84568       288      GIRLS ALPHABET IRON ON PATCHES
#    22335       288       HEART DECORATION PAINTED ZINC
#    71459        96       HANGING JAM JAR T-LIGHT HOLDER
#    22252        96  BIRDCAGE DECORATION TEALIGHT HOLDER
#    85204        96         HANGING WOOD AND FELT FLOWER
#    22335        96       HEART DECORATION PAINTED ZINC
#    84950        96       ASSORTED COLOUR T-LIGHT HOLDER
#    22151        72            PLACE SETTING WHITE HEART
#    21326        72     AGED GLASS SILVER T-LIGHT HOLDER
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Cyprus
# StockCode  Quantity                        Description
#   15056N       -33          EDWARDIAN PARASOL NATURAL
#    23245        -2         SET OF 3 REGENCY CAKE TINS
#    22797        -2    CHEST OF DRAWERS GINGHAM HEART
#    22666        -2    RECIPE BOX PANTRY YELLOW DESIGN
#    22839        -2    3 TIER CAKE TIN GREEN AND CREAM
#    22826        -1      LOVE SEAT ANTIQUE WHITE METAL
#        M        -1                             Manual
#    22720        -1  SET OF 3 CAKE TINS PANTRY DESIGN
#    22746         1      POPPY'S PLAYHOUSE LIVINGROOM
#    22141         1     CHRISTMAS CRAFT TREE TOP ANGEL
#
#
# Top 10 Items By Price in Cyprus
# StockCode  UnitPrice                         Description
#        M     320.69                              Manual
#        M     320.69                              Manual
#    22827     145.00  RUSTIC  SEVENTEEN DRAWER SIDEBOARD
#    22827     145.00  RUSTIC  SEVENTEEN DRAWER SIDEBOARD
#    22656     125.00        VINTAGE BLUE KITCHEN CABINET
#    22656     125.00        VINTAGE BLUE KITCHEN CABINET
#    22655     125.00         VINTAGE RED KITCHEN CABINET
#    22655     125.00         VINTAGE RED KITCHEN CABINET
#    22826      85.00       LOVE SEAT ANTIQUE WHITE METAL
#    22826      42.50       LOVE SEAT ANTIQUE WHITE METAL
#
#
# 10 Least Priced Items / Cancelled Items in Cyprus
# StockCode  UnitPrice                      Description
#    85204       0.12     HANGING WOOD AND FELT FLOWER
#    84598       0.21    BOYS ALPHABET IRON ON PATCHES
#    16238       0.21        PARTY TIME PENCIL ERASERS
#    84199       0.21            GLOW IN DARK DOLPHINS
#    84568       0.21  GIRLS ALPHABET IRON ON PATCHES
#    22616       0.29       PACK OF 12 LONDON TISSUES
#    22066       0.39           LOVE HEART TRINKET POT
#   51014A       0.39             FEATHER PEN,HOT PINK
#    22816       0.42             CARD MOTORBIKE SANTA
#    22818       0.42           CARD CHRISTMAS VILLAGE
#
#
#
# Top 10 Items Purchased by customers in Sweden
# StockCode  Quantity                          Description
#    20975       768  12 PENCILS SMALL TUBE RED RETROSPOT
#    15036       720            ASSORTED COLOURS SILK FAN
#    23310       720              BUBBLEGUM RING ASSORTED
#    22492       576              MINI PAINT SET VINTAGE
#    84077       576    WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    22492       576              MINI PAINT SET VINTAGE
# ...
#    84077       0.21  WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    21829       0.21         DINOSAUR KEYRINGS ASSORTED
#   84926D       0.29           LA PALMIERA TILE COASTER
#   84926A       0.29      WAKE UP COCKEREL TILE COASTER
#    20984       0.29          12 PENCILS TALL TUBE POSY
#    37467       0.39      PIG MUG IN TWO COLOUR DESIGNS
#   47593B       0.39              SCOTTIE DOGS BABY BIB
#    22402       0.39  MAGNETS PACK OF 4 VINTAGE COLLAGE
#    22396       0.39      MAGNETS PACK OF 4 RETRO PHOTO
#
#
#
# Top 10 Items Purchased by customers in Unspecified
# StockCode  Quantity                         Description
#   47021G        48  SET/6 BEAD COASTERS GAUZE BAG GOLD
#    84077        48   WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    84077        48   WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    22439        40                  6 ROCKET BALLOONS
#    23310        36             BUBBLEGUM RING ASSORTED
#    22952        36     60 CAKE CASES VINTAGE CHRISTMAS
#    23119        36       PACK OF 6 LARGE FRUIT STRAWS
#    21500        25                 PINK POLKADOT WRAP
#    21499        25                  BLUE POLKADOT WRAP
#   16161P        25                  WRAP ENGLISH ROSE
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Unspecified
# StockCode  Quantity                        Description
#    23082         1  SET 6 PAPER TABLE LANTERN HEARTS
#    23128         1        FELTCRAFT BOY JEAN-PAUL KIT
#    23241         1       TREASURE TIN GYMKHANA DESIGN
#    22325         1             MOBILE VINTAGE HEARTS
#    22150         1           3 STRIPEY MICE FELTCRAFT
#    22834         1        HAND WARMER BABUSHKA DESIGN
#    22580         1       ADVENT CALENDAR GINGHAM SACK
#   47348A         1      FUSCHIA VOILE POINTY SHOE DEC
#    22150         1           3 STRIPEY MICE FELTCRAFT
#    23211         1     RED ROCKING HORSE HAND PAINTED
#
#
# Top 10 Items By Price in Unspecified
# StockCode  UnitPrice                      Description
#    22846      16.95       BREAD BIN DINER STYLE RED
#    23007      16.95           SPACEBOY BABY GIFT SET
#    23008      16.95         DOLLY GIRL BABY GIFT SET
#    23007      16.95           SPACEBOY BABY GIFT SET
#    22839      14.95  3 TIER CAKE TIN GREEN AND CREAM
#    21628      14.95       TRIANGULAR POUFFE VINTAGE
#    22838      14.95    3 TIER CAKE TIN RED AND CREAM
#    22423      12.75         REGENCY CAKESTAND 3 TIER
#    22485      12.75    SET OF 2 WOODEN MARKET CRATES
#    22485      12.75    SET OF 2 WOODEN MARKET CRATES
#
#
# 10 Least Priced Items / Cancelled Items in Unspecified
# StockCode  UnitPrice                          Description
#   79063C       0.19    RETRO PILL BOX KEY CHAIN,THE KING
#    16012       0.21           FOOD/DRINK SPONGE STICKERS
#    84077       0.29    WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    84077       0.29    WORLD WAR 2 GLIDERS ASSTD DESIGNS
#    85213       0.29       MINI  ZINC GARDEN DECORATIONS
#    85212       0.29      MINI PAINTED GARDEN DECORATION
#    35968       0.38  FOLK ART METAL HEART T-LIGHT HOLDER
#    20868       0.39                 SILVER FABRIC MIRROR
#   47021G       0.39   SET/6 BEAD COASTERS GAUZE BAG GOLD
#   47348A       0.39        FUSCHIA VOILE POINTY SHOE DEC
#
#
#
# Top 10 Items Purchased by customers in Brazil
# StockCode  Quantity                         Description
#    22697        24     GREEN REGENCY TEACUP AND SAUCER
#    22698        24      PINK REGENCY TEACUP AND SAUCER
#   84971S        24           SMALL HEART FLOWERS HOOK
#    21430        24  SET/3 RED GINGHAM ROSE STORAGE BOX
#    22630        24                DOLLY GIRL LUNCH BOX
#    22722        24   SET OF 6 SPICE TINS PANTRY DESIGN
#    22993        24        SET OF 4 PANTRY JELLY MOULDS
#    22699        24    ROSES REGENCY TEACUP AND SAUCER
#    22423        16            REGENCY CAKESTAND 3 TIER
#    21166        12          COOK WITH WINE METAL SIGN
# 10 Items Least Purchased / Cancelled Items by customers in Brazil
# StockCode  Quantity                      Description
#    23049         2        RECYCLED ACAPULCO MAT RED
#    23051         2       RECYCLED ACAPULCO MAT BLUE
#    23050         2      RECYCLED ACAPULCO MAT GREEN
#    23053         2       RECYCLED ACAPULCO MAT PINK
#    23054         2   RECYCLED ACAPULCO MAT LAVENDER
#    23052         2  RECYCLED ACAPULCO MAT TURQUOISE
#  15056BL         3          EDWARDIAN PARASOL BLACK
#   15056P         3           EDWARDIAN PARASOL PINK
#   15056N         3        EDWARDIAN PARASOL NATURAL
#    20679         3            EDWARDIAN PARASOL RED
#
#
# Top 10 Items By Price in Brazil
# StockCode  UnitPrice                      Description
#    22423      10.95         REGENCY CAKESTAND 3 TIER
#    23052       8.25  RECYCLED ACAPULCO MAT TURQUOISE
#    23049       8.25        RECYCLED ACAPULCO MAT RED
#    23051       8.25       RECYCLED ACAPULCO MAT BLUE
#    23050       8.25      RECYCLED ACAPULCO MAT GREEN
#    23053       8.25       RECYCLED ACAPULCO MAT PINK
#    23054       8.25   RECYCLED ACAPULCO MAT LAVENDER
#    22366       6.75                 DOORMAT AIRMAIL
#    21906       6.75          PHARMACIE FIRST AID TIN
#    20679       5.95            EDWARDIAN PARASOL RED
#
#
# 10 Least Priced Items / Cancelled Items in Brazil
# StockCode  UnitPrice                         Description
#   84971S       0.85           SMALL HEART FLOWERS HOOK
#    22494       1.25            EMERGENCY FIRST AID TIN
#    22993       1.25        SET OF 4 PANTRY JELLY MOULDS
#    22488       1.65  NATURAL SLATE RECTANGLE CHALKBOARD
#    22382       1.65          LUNCH BAG SPACEBOY DESIGN
#    22662       1.65         LUNCH BAG DOLLY GIRL DESIGN
#    22630       1.95                DOLLY GIRL LUNCH BOX
#    22629       1.95                 SPACEBOY LUNCH BOX
#    21166       2.08          COOK WITH WINE METAL SIGN
#    21181       2.10        PLEASE ONE PERSON METAL SIGN
#
#
#
# Top 10 Items Purchased by customers in USA
# StockCode  Quantity                          Description
#    20975        72  12 PENCILS SMALL TUBE RED RETROSPOT
#    23366        72       SET 12 COLOURING PENCILS DOILY
#    21121        48    SET/10 RED POLKADOT PARTY CANDLES
#    21124        48   SET/10 BLUE POLKADOT PARTY CANDLES
#    21122        48   SET/10 PINK POLKADOT PARTY CANDLES
#    21123        48  SET/10 IVORY POLKADOT PARTY CANDLES
#    22129        36    PARTY CONES CANDY TREE DECORATION
#    22492        36              MINI PAINT SET VINTAGE
#    23158        36          SET OF 5 LUCKY CAT MAGNETS
#    22907        36     PACK OF 20 NAPKINS PANTRY DESIGN
#
#
# 10 Items Least Purchased / Cancelled Items by customers in USA
# StockCode  Quantity                  Description
#    23158       -36  SET OF 5 LUCKY CAT MAGNETS
#    22492       -36      MINI PAINT SET VINTAGE
#    22050       -25  PINK PAISLEY ROSE GIFT WRAP
#    22048       -25   BIRTHDAY BANQUET GIFT WRAP
#    21498       -25          RED RETROSPOT WRAP
#   16161P       -25           WRAP ENGLISH ROSE
#    22708       -25              WRAP DOLLY GIRL
#    21499       -25           BLUE POLKADOT WRAP
#    22046       -25   TEA PARTY  WRAPPING PAPER
#    22706       -25               WRAP COWBOYS
#
#
# Top 10 Items By Price in USA
# StockCode  UnitPrice                     Description
#    22848      16.95      BREAD BIN DINER STYLE PINK
#    22848      16.95      BREAD BIN DINER STYLE PINK
#    22423      12.75        REGENCY CAKESTAND 3 TIER
#    22423      12.75        REGENCY CAKESTAND 3 TIER
#    23173       9.95           REGENCY TEAPOT ROSES
#    48185       8.25              DOORMAT FAIRY CAKE
#    21524       8.25  DOORMAT SPOTTY HOME SWEET HOME
#    21524       8.25  DOORMAT SPOTTY HOME SWEET HOME
#    48185       8.25              DOORMAT FAIRY CAKE
#    20750       7.95        RED RETROSPOT MINI CASES
#
#
# 10 Least Priced Items / Cancelled Items in USA
# StockCode  UnitPrice                 Description
#    21507       0.42     ELEPHANT BIRTHDAY CARD
#    21499       0.42          BLUE POLKADOT WRAP
#    22027       0.42     TEA PARTY BIRTHDAY CARD
#    22029       0.42      SPACEBOY BIRTHDAY CARD
#    22046       0.42  TEA PARTY  WRAPPING PAPER
#    22048       0.42  BIRTHDAY BANQUET GIFT WRAP
#    22706       0.42              WRAP COWBOYS
#    22708       0.42             WRAP DOLLY GIRL
#    22712       0.42            CARD DOLLY GIRL
#    22818       0.42      CARD CHRISTMAS VILLAGE
#
#
#
# Top 10 Items Purchased by customers in European Community
# StockCode  Quantity                          Description
#    23308        24   SET OF 60 VINTAGE LEAF CAKE CASES
#    22571        24         ROCKING HORSE RED CHRISTMAS
#    23210        24     WHITE ROCKING HORSE HAND PAINTED
#    23211        24       RED ROCKING HORSE HAND PAINTED
#    22572        24       ROCKING HORSE GREEN CHRISTMAS
#    23307        24  SET OF 60 PANTRY DESIGN CAKE CASES
#    23270        12     SET OF 2 CERAMIC PAINTED HEARTS
#    22314        12          OFFICE MUG WARMER CHOC+BLUE
#    22319        12    HAIRCLIPS FORTIES FABRIC ASSORTED
#    22961        12               JAM MAKING SET PRINTED
#
#
# 10 Items Least Purchased / Cancelled Items by customers in European Community
# StockCode  Quantity                      Description
#    22960        -2         JAM MAKING SET WITH JARS
#    22839         1  3 TIER CAKE TIN GREEN AND CREAM
#    23020         1      GLASS  SONGBIRD STORAGE JAR
#    22424         1           ENAMEL BREAD BIN CREAM
#    22840         2       ROUND CAKE TIN VINTAGE RED
#    22841         2     ROUND CAKE TIN VINTAGE GREEN
#    23111         2            PARISIENNE SEWING BOX
#    22842         2          BISCUIT TIN VINTAGE RED
#    22843         2        BISCUIT TIN VINTAGE GREEN
#    22193         2             RED DINER WALL CLOCK
#
#
# Top 10 Items By Price in European Community
# StockCode  UnitPrice                      Description
#     POST      18.00                          POSTAGE
#     POST      15.00                          POSTAGE
#     POST      15.00                          POSTAGE
#    22839      14.95  3 TIER CAKE TIN GREEN AND CREAM
#    22838      14.95    3 TIER CAKE TIN RED AND CREAM
#    22424      12.75           ENAMEL BREAD BIN CREAM
#    23020      12.50      GLASS  SONGBIRD STORAGE JAR
#    23111      12.50            PARISIENNE SEWING BOX
#    22193       8.50             RED DINER WALL CLOCK
#    22840       7.95       ROUND CAKE TIN VINTAGE RED
#
#
# 10 Least Priced Items / Cancelled Items in European Community
# StockCode  UnitPrice                          Description
#    23307       0.55  SET OF 60 PANTRY DESIGN CAKE CASES
#    23308       0.55   SET OF 60 VINTAGE LEAF CAKE CASES
#    22319       0.65    HAIRCLIPS FORTIES FABRIC ASSORTED
#    22571       0.85         ROCKING HORSE RED CHRISTMAS
#    22572       0.85       ROCKING HORSE GREEN CHRISTMAS
#    21677       0.85                     HEARTS  STICKERS
#    21676       0.85                    FLOWERS  STICKERS
#    21675       0.85                 BUTTERFLIES STICKERS
#    21098       1.25                CHRISTMAS TOILET ROLL
#    23211       1.25       RED ROCKING HORSE HAND PAINTED
#
#
#
# Top 10 Items Purchased by customers in Malta
# StockCode  Quantity                       Description
#    22065        48    CHRISTMAS PUDDING TRINKET POT
#    72741        45             GRAND CHOCOLATECANDLE
#    22959        25            WRAP CHRISTMAS VILLAGE
#   85034C        24       3 ROSE MORRIS BOXED CANDLES
#    21982        24          PACK OF 12 SUKI TISSUES
#    21984        24  PACK OF 12 PINK PAISLEY TISSUES
#    23226        24        FILIGREE HEART DAISY WHITE
#   85230A        24       OPIUM SCENTED VOTIVE CANDLE
#    23228        24        FILIGREE HEART BIRD WHITE
#    22307        24  GOLD MUG BONE CHINA TREE OF LIFE
#
#
# 10 Items Least Purchased / Cancelled Items by customers in Malta
# StockCode  Quantity                          Description
#    22065        -4       CHRISTMAS PUDDING TRINKET POT
#    72741        -3                GRAND CHOCOLATECANDLE
#    72741        -3                GRAND CHOCOLATECANDLE
#   72807A        -2    SET/3 ROSE CANDLE IN JEWELLED BOX
#    22768        -2           FAMILY PHOTO FRAME CORNICE
#     POST        -2                              POSTAGE
#    22768        -2           FAMILY PHOTO FRAME CORNICE
#    22307        -1     GOLD MUG BONE CHINA TREE OF LIFE
#   72807C        -1  SET/3 VANILLA SCENTED CANDLE IN BOX
#    22768        -1           FAMILY PHOTO FRAME CORNICE
#
#
# Top 10 Items By Price in Malta
# StockCode  UnitPrice                         Description
#     POST      65.00                             POSTAGE
#     POST      65.00                             POSTAGE
#     POST      40.00                             POSTAGE
#     POST      40.00                             POSTAGE
#    23253      15.95  16 PIECE CUTLERY SET PANTRY DESIGN
#    22423      12.75            REGENCY CAKESTAND 3 TIER
#    23173       9.95               REGENCY TEAPOT ROSES
#    37449       9.95  CERAMIC CAKE STAND + HANGING CAKES
#    22767       9.95         TRIPLE PHOTO FRAME CORNICE
#    22796       9.95       PHOTO FRAME 3 CLASSIC HANGING
#
#
# 10 Least Priced Items / Cancelled Items in Malta
# StockCode  UnitPrice                       Description
#   84251B       0.19      GREETING CARD, STICKY GORDON
#    21982       0.29          PACK OF 12 SUKI TISSUES
#    21984       0.29  PACK OF 12 PINK PAISLEY TISSUES
#   85230A       0.29       OPIUM SCENTED VOTIVE CANDLE
#    22065       0.39    CHRISTMAS PUDDING TRINKET POT
#    22818       0.42            CARD CHRISTMAS VILLAGE
#    22983       0.42               CARD BILLBOARD FONT
#    22984       0.42                CARD GINGHAM ROSE
#    22959       0.42            WRAP CHRISTMAS VILLAGE
#   72140E       0.85           BEST DAD CANDLE LETTERS
#
#
#
# Top 10 Items Purchased by customers in RSA
# StockCode  Quantity                        Description
#    22915        12      ASSORTED BOTTLE TOP  MAGNETS
#    84375        12      SET OF 20 KIDS COOKIE CUTTERS
#    22620        12        4 TRADITIONAL SPINNING TOPS
#    22585        12          PACK OF 6 BIRDY GIFT TAGS
#    21889        12             WOODEN BOX OF DOMINOES
#    20718        10          RED RETROSPOT SHOPPER BAG
#    22411        10  JUMBO SHOPPER VINTAGE RED PAISLEY
#    22478        10           BIRDHOUSE GARDEN MARKER
#    22384        10            LUNCH BAG PINK POLKADOT
#    20725        10            LUNCH BAG RED RETROSPOT
#
#
# 10 Items Least Purchased / Cancelled Items by customers in RSA
# StockCode  Quantity                     Description
#        M         1                          Manual
#    23081         2   GREEN METAL BOX ARMY SUPPLIES
#    22423         2        REGENCY CAKESTAND 3 TIER
#    22625         2              RED KITCHEN SCALES
#    22624         2            IVORY KITCHEN SCALES
#    23284         2   DOORMAT KEEP CALM AND COME IN
#    23407         2  SET OF 2 TRAYS HOME SWEET HOME
#    85066         2     CREAM SWEETHEART MINI CHEST
#    48138         2              DOORMAT UNION FLAG
#    22526         2       WHEELBARROW FOR CHILDREN
#
#
# Top 10 Items By Price in RSA
# StockCode  UnitPrice                          Description
#    22605      14.95            WOODEN CROQUET GARDEN SET
#    85066      12.75          CREAM SWEETHEART MINI CHEST
#    21340      12.75  CLASSIC METAL BIRDCAGE PLANT HOLDER
#    22526      12.75            WHEELBARROW FOR CHILDREN
#    22423      12.75             REGENCY CAKESTAND 3 TIER
#    23407       9.95       SET OF 2 TRAYS HOME SWEET HOME
#    23316       9.95                 RED REFECTORY CLOCK
#    22624       8.50                 IVORY KITCHEN SCALES
#    22625       8.50                   RED KITCHEN SCALES
#    23284       8.25        DOORMAT KEEP CALM AND COME IN
#
#
# 10 Least Priced Items / Cancelled Items in RSA
# StockCode  UnitPrice                      Description
#        M       0.00                           Manual
#    22915       0.42    ASSORTED BOTTLE TOP  MAGNETS
#    23205       0.85  CHARLOTTE BAG VINTAGE ALPHABET
#    21238       0.85                RED RETROSPOT CUP
#    20718       1.25        RED RETROSPOT SHOPPER BAG
#    20676       1.25               RED RETROSPOT BOWL
#    21889       1.25           WOODEN BOX OF DOMINOES
#    20677       1.25               PINK POLKADOT BOWL
#    22478       1.25         BIRDHOUSE GARDEN MARKER
#    22585       1.25        PACK OF 6 BIRDY GIFT TAGS

# %%
# 7 Identify Busiest Day of the week

day_week_map = {0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',5:'Saturday',6:'Sunday'}

# function to find number of customers visiting each day
def findBusiestDay(df):
    ts_list = pd.to_datetime(df['InvoiceDate']).apply(lambda x: x.date())
    ts_list_tup = [tuple(str(x).split('-')) for x in ts_list]
    weekday_list = [day_week_map.get(dt.date(int(x[0]),int(x[1]),int(x[2])).weekday(),'Unknown') for x in ts_list_tup]
    day_freq_map = {}
    for day in weekday_list:
        day_freq_map[day] = day_freq_map.get(day,0)+1
    return day_freq_map
    
# calling weekday fuction to find busiest day of the week 
day_freq_map = findBusiestDay(retail_landing_df)
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
freqs=[]
for day in days:
    freqs.append(day_freq_map.get(day,0))
    
#fig, ax = plt.subplots(1,1)
day_ticks = range(0,7)
day_lables = days
plt.bar(day_ticks,freqs)
plt.xlabel("Day")
plt.ylabel("Visit Count")
plt.title(" Day by Day Visit Count for Entire Dataset")
plt.xticks(day_ticks, rotation=60)
plt.xlabel(day_lables)
plt.show()
plt.savefig('top-visits-complete-dataset.svg',format='svg')

# %%
# Busy Days by country

days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
for country in country_list:
    item_df = retail_landing_df[(retail_landing_df.Country == country)]
    day_freq_map = findBusiestDay(item_df)
    
    freqs=[]
    for day in days:
        freqs.append(day_freq_map.get(day,0))
    
    #fig, ax = plt.subplots(1,1)
    day_ticks = range(0,7)
    day_lables = days
    plt.bar(day_ticks,freqs)
    plt.xlabel("Day")
    plt.ylabel("Visit Count")
    plt.title(" Day by Day Visit Count for " + country)
    plt.xticks(day_ticks, rotation=60)
    plt.xlabel(day_lables)
    plt.show()

# %%
#Creating a new dataframe with only the required columns
customer_details_df = retail_landing_df[['CustomerID','InvoiceNo','Quantity','UnitPrice']]
customer_details_df.head()
# Out:
#    CustomerID InvoiceNo  Quantity  UnitPrice
# 0     17850.0    536365         6       2.55
# 1     17850.0    536365         6       3.39
# 2     17850.0    536365         8       2.75
# 3     17850.0    536365         6       3.39
# 4     17850.0    536365         6       3.39

# %%
#Generating top customers by total value of purchases


#Getting the total value of purchase per each item per a invoice number
total_val = customer_details_df[['Quantity','UnitPrice']].product(axis=1)
temp_df = pd.DataFrame(total_val, index=customer_details_df.index, columns=['TotalValue'])

#Creating a new dataframe that contains a column with purchase value per item per invoice number
purchase_customers = pd.concat([customer_details_df,temp_df], axis=1)
purchase_customers['CustomerID'] = purchase_customers['CustomerID'].replace(np.nan, -1)


#Getting the total value of purchases made by the customer in the entire year.
purchase_customers[['CustomerID']] = purchase_customers[['CustomerID']].astype(int)
allpurchase_customer = purchase_customers.groupby('CustomerID').TotalValue.agg('sum')


#creating a list of customerID's
customer_index = []
for i in allpurchase_customer:
    customer_index += list(allpurchase_customer[allpurchase_customer == i].index)


#A dictonary that maps customerID's to total value of purchases
customer_total_purchase = {}
for customer in customer_index:
    if customer != -1:
        customer_total_purchase[customer] = allpurchase_customer[customer]

temp_df = pd.DataFrame({'total_purchase':allpurchase_customer.values, 'CustomerID':allpurchase_customer.index})

#Puting the result of the top 20 customers as per purchase value into a dataframe
final_df = pd.DataFrame()
for k in sorted(customer_total_purchase, key=customer_total_purchase.get, reverse=True)[:20]:
    temp = temp_df[temp_df['CustomerID']== k]
    final_df = pd.concat([final_df,temp])
final_df
# Out:
#       CustomerID  total_purchase
# 1704       14646       279489.02
# 4234       18102       256438.49
# 3759       17450       187482.17
# 1896       14911       132572.62
# 56         12415       123725.45
# 1346       14156       113384.14
# 3802       17511        88125.38
# 3203       16684        65892.08
# 1006       13694        62653.10
# 2193       15311        59419.34
# 569        13089        57385.88
# 1301       14096        57120.91
# 2000       15061        54228.74
# 4126       17949        52750.84
# 2538       15769        51823.72
# 2723       16029        50992.61
# 1448       14298        50862.44
# 1296       14088        50415.49
# 4043       17841        40340.78
# 1079       13798        36351.42

# %%
#Top customers by most visits
transactions_per_customer = purchase_customers.groupby('CustomerID').InvoiceNo.agg('count')

#A dictonary that maps customerID's to total transactions per customer ID
customer_total_transactions = {}
for customer in customer_index:
    if customer != -1:
        customer_total_transactions[customer] = transactions_per_customer[customer]

temp1_df = pd.DataFrame({'total_transactions':transactions_per_customer.values, 'CustomerID':transactions_per_customer.index})

#Puting the result of the top 20 customers as per total transactions into a dataframe
final1_df = pd.DataFrame()
for k in sorted(customer_total_transactions, key=customer_total_transactions.get, reverse=True)[:20]:
    temp = temp1_df[temp1_df['CustomerID']== k]
    final1_df = pd.concat([final1_df,temp])
final1_df
# Out:
#       CustomerID  total_transactions
# 4043       17841                7983
# 1896       14911                5903
# 1301       14096                5128
# 331        12748                4642
# 1675       14606                2782
# 2193       15311                2491
# 1704       14646                2085
# 569        13089                1857
# 699        13263                1677
# 1448       14298                1640
# 1981       15039                1508
# 1346       14156                1420
# 4246       18118                1284
# 1349       14159                1212
# 1814       14796                1165
# 1954       15005                1160
# 2726       16033                1152
# 1274       14056                1128
# 1795       14769                1094
# 3802       17511                1076

# %% [markdown]
# ## Implementing Clustering Algorithms on dataset  : K-means and Agglomerative

# %% [markdown]
# ### K-means Clustering

# %%
# Clustering based on each country 

# Filtering dataset by country

def getByCountry(df, country):
    return df[(df.Country==country) & (df.TotalPrice > 0) & (df.TotalPrice < 1000)]

for country in country_list:
    
    country_df = getByCountry(retail_landing_df, country)
    if(country_df.shape[0]<10):
        continue;

    #calculating avg quantity per invoice per customer
    avg_quant_per_inv = country_df.groupby(['CustomerID','InvoiceNo'])['Quantity'].mean().to_frame().reset_index()
    avg_quant_per_id = avg_quant_per_inv.groupby(['CustomerID'])['Quantity'].mean().to_frame().reset_index()

    #calculating avg price per invoice per customer
    avg_price_per_inv = country_df.groupby(['CustomerID','InvoiceNo'])['TotalPrice'].mean().to_frame().reset_index()
    avg_price_per_id = avg_price_per_inv.groupby(['CustomerID'])['TotalPrice'].mean().to_frame().reset_index()

    # setting number of clusters . We have tried different cluster numbers and found that 3 is optimal numbers
    number_of_clusters = 3
    cluster_df = pd.merge(avg_quant_per_id,avg_price_per_id)
    if(cluster_df.shape[0] < number_of_clusters):
        continue;
    
    # using k-means algorithm from scikit learn
    kmeans = KMeans(n_clusters=number_of_clusters)
    kmeans.fit(cluster_df[['TotalPrice','Quantity']])
    # storing cluster numbers
    labels = kmeans.labels_
    # list of colors. used to assign colors to cluster labels
    colors_list=['r','g','b','y','m','c','k']
    # assigning colors to cluster labels
    color_cluster = [colors_list[x] for x in labels]
    
    # Generating Cluster plot 
    plt.title(" Cluster Plot for " + country)
    plt.xlabel("Total Price")
    plt.ylabel("Quantity")
    plt.scatter(cluster_df['TotalPrice'],cluster_df['Quantity'],color=color_cluster)
    plt.show()

# %% [markdown]
# ### Agglomorative Clustering

# %%
# Agglomerative clustering 

for country in country_list:
    
    country_df = getByCountry(retail_landing_df, country)
    if(country_df.shape[0]<10):
        continue;

    #calculating avg quantity per invoice per customer
    avg_quant_per_inv = country_df.groupby(['CustomerID','InvoiceNo'])['Quantity'].mean().to_frame().reset_index()
    avg_quant_per_id = avg_quant_per_inv.groupby(['CustomerID'])['Quantity'].mean().to_frame().reset_index()

    #calculating avg price per invoice per customer
    avg_price_per_inv = country_df.groupby(['CustomerID','InvoiceNo'])['TotalPrice'].mean().to_frame().reset_index()
    avg_price_per_id = avg_price_per_inv.groupby(['CustomerID'])['TotalPrice'].mean().to_frame().reset_index()

    # setting number of clusters . We have tried different cluster numbers and found that 3 is optimal numbers
    number_of_clusters = 3
    cluster_df = pd.merge(avg_quant_per_id,avg_price_per_id)
    if(cluster_df.shape[0] < number_of_clusters):
        continue;
    
    # using k-means algorithm from scikit learn
    agglo = AgglomerativeClustering(n_clusters=number_of_clusters, linkage='average')
    agglo.fit(cluster_df[['TotalPrice','Quantity']])
    # storing cluster numbers
    labels = agglo.labels_
    # list of colors. used to assign colors to cluster labels
    colors_list=['r','g','b','y','m','c','k']
    # assigning colors to cluster labels
    color_cluster = [colors_list[x] for x in labels]
    
    # Generating Cluster plot 
    plt.title(" Cluster Plot for " + country)
    plt.xlabel("Total Price")
    plt.ylabel("Quantity")
    plt.scatter(cluster_df['TotalPrice'],cluster_df['Quantity'],color=color_cluster)
    plt.show()

# %% [markdown]
# # For the code snippets following this, the input file 'Online_Retail.csv' should contain the columns
# # in the following order
#
# - InvoiceNo
# - StockCode
# - Quantity
# - InvoiceDate
# - UnitPrice
# - CustomerID
# - Country
#
# Note: Description column is to be deleted from the dataset

# %%
filePath = 'Online_Retail.csv';

# %% [markdown]
# # K-Means on given data
#
# The below method applies K-Means algorithm on the given data set, and plots the final result. It also generates VECTOR GRAPHICS for the plots.
#
# # K-Means Algorithm parameters:
# - Algorithm Type: k-means++
#
# - Number of iterations: 10
#
# - Intial centroids selection: auto

# %%
def plot_KMeans(data_list, num_of_clusters, filename):
    colors = ["g.","r.","c.","y.", "b.","lime","brown","pink","navy", "grey"]
    X = np.array(data_list)
    # Running K-Means on the dataset
    kmeans = KMeans(n_clusters=num_of_clusters, random_state=0, 
                    init='k-means++', n_init=10, algorithm='auto').fit(X)
    centroids = kmeans.cluster_centers_
    labels = kmeans.labels_

    for i in range(len(X)):
        plt.plot(X[i][0], X[i][1], colors[labels[i]], markersize = 10)

    plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)
    plt.title(filename)
    plt.xlabel('Avg. Quantity')
    plt.ylabel('Avg. Price')
    # EXTRACTING THE PLOT USING VECTOR GRAPHICS
    plt.savefig(filename+'.svg')
    plt.show()

# %% [markdown]
# # Read the input CSV file and organize the data to compute Avg. quantity vs Avg. price for each of the customers from United Kingdom, France, and Germany.
#
# The data is segregated by day of week and month of year

# %%
LINE_SEPERATOR = '\n'
formatStr = '{0:.2f}'
customerDataByMonth = {}
customerDataByDay = {}
with open(filePath, newline='') as csvfile:
    csvReader = csv.reader(csvfile, delimiter=',', quotechar='|')
    header = next(csvReader)
    for line in csvReader:
        quantity = int(line[2])
        if quantity <= 0:
            continue
        order_date = line[3]
        price = float(line[4])
        customerId = line[5]
        if not bool(customerId.strip()):
            customerId = 'UNKNOWN'
        country = line[6]
        
        order_date = time.strptime(order_date, "%d-%m-%y %H:%M")
        # Determine "day of week" and "month of year" from the order date
        month = calendar.month_name[order_date.tm_mon]
        day = calendar.day_name[order_date.tm_wday]
        
        if country not in customerDataByMonth:
            customerDataByMonth[country] = {}
            customerDataByDay[country] = {}
        
        if month not in customerDataByMonth[country]:
            customerDataByMonth[country][month] = {}
        
        if day not in customerDataByDay[country]:
            customerDataByDay[country][day] = {}
        
        if customerId not in customerDataByMonth[country][month]:
            # List of three values:
            # First value indicates Quantity of purchase
            # Second value indicates Price of purchase
            # Third value keeps count of purchases made(repeated customers). Need this to compute average
            customerDataByMonth[country][month][customerId] = [0,0,0]
        
        if customerId not in customerDataByDay[country][day]:
            # List of three values:
            # First value indicates Quantity of purchase
            # Second value indicates Price of purchase
            # Third value keeps count of purchases made(repeated customers). Need this to compute average
            customerDataByDay[country][day][customerId] = [0,0,0]
        
        customerDataByMonth[country][month][customerId][0] += quantity
        customerDataByMonth[country][month][customerId][1] += price
        customerDataByMonth[country][month][customerId][2]+=1
        
        customerDataByDay[country][day][customerId][0] += quantity
        customerDataByDay[country][day][customerId][1] += price
        customerDataByDay[country][day][customerId][2]+=1

totalCustomers = len(customerDataByMonth)

# %% [markdown]
# # Apply K-Means and plot Avg. quantity vs Avg. price for day of week analysis

# %%
# We have considered customers who have made a certain number of transactions that is above a cut-off
# (specific to each country) 
def getMinCountByForDayCountry(country):
    if country == 'United Kingdom':
        return 200
    elif country == 'France':
        return 40
    elif country == 'Germany':
        return 25

def getClustersForDay(day, country):
    if country == 'United Kingdom':
        if day == 'Wednesday': return 5
        if day == 'Thursday': return 4
        if day == 'Friday': return 4
        if day == 'Sunday': return 4
        if day == 'Monday': return 4
        if day == 'Tuesday': return 4
    elif country == 'France':
        if day == 'Wednesday': return 3
        if day == 'Thursday': return 4
        if day == 'Friday': return 3
        if day == 'Sunday': return 3
        if day == 'Monday': return 4
        if day == 'Tuesday': return 4
    elif country == 'Germany':
        if day == 'Wednesday': return 3
        if day == 'Thursday': return 3
        if day == 'Friday': return 4
        if day == 'Sunday': return 4
        if day == 'Monday': return 5
        if day == 'Tuesday': return 5

for country in customerDataByDay:
    if country != 'Germany' and country != 'United Kingdom' and country != 'France':
        continue
    for day in customerDataByDay[country]:
        data_list = list()
        minTrxCount = getMinCountByForDayCountry(country)
        for customer in customerDataByDay[country][day]:
            data = customerDataByDay[country][day][customer]
            if data[2] < minTrxCount:
                continue
            # Compute Avg. Quantity and Avg. Price, to plot K-Means
            avgQuantity = data[0]/data[2]
            avgPrice = data[1]/data[2]
            data_list.append(tuple((avgQuantity,avgPrice)))
        filename = ''+country+'-'+day
        plot_KMeans(data_list, getClustersForDay(day,country),filename)

# %% [markdown]
# # Apply K-Means and plot Avg. quantity vs Avg. price for month of year analysis

# %%
# We have considered customers who have made a certain number of transactions that is above a cut-off
# (specific to each country) 
def getMinCountByMonthForCountry(country):
    if country == 'United Kingdom':
        return 100
    elif country == 'France':
        return 25
    elif country == 'Germany':
        return 25
    

def getClustersForMonth(month,country):
    if country == 'United Kingdom':
        if month == 'December': return 2
        if month == 'January': return 2
        if month == 'February': return 3
        if month == 'March': return 3
        if month == 'April': return 3
        if month == 'May': return 3
        if month == 'June': return 3
        if month == 'July': return 3
        if month == 'August': return 3
        if month == 'September': return 3
        if month == 'October': return 3
        if month == 'November': return 3
    elif country == 'France':
        if month == 'December': return 3
        if month == 'January': return 4
        if month == 'February': return 3
        if month == 'March': return 3
        if month == 'April': return 2
        if month == 'May': return 4
        if month == 'June': return 3
        if month == 'July': return 4
        if month == 'August': return 3
        if month == 'September': return 3
        if month == 'October': return 3
        if month == 'November': return 3
    elif country == 'Germany':
        if month == 'December': return 4
        if month == 'January': return 4
        if month == 'February': return 2
        if month == 'March': return 3
        if month == 'April': return 3
        if month == 'May': return 4
        if month == 'June': return 4
        if month == 'July': return 4
        if month == 'August': return 4
        if month == 'September': return 5
        if month == 'October': return 3
        if month == 'November': return 5
    
for country in customerDataByMonth:
    if country != 'Germany' and country != 'United Kingdom' and country != 'France':
        continue
    for month in customerDataByMonth[country]:
        data_list = list()
        minTrxCount = getMinCountByMonthForCountry(country)
        for customer in customerDataByMonth[country][month]:
            data = customerDataByMonth[country][month][customer]
            if data[2] < minTrxCount:
                continue
            # Compute Avg. Quantity and Avg. Price, to plot K-Means
            avgQuantity = data[0]/data[2]
            avgPrice = data[1]/data[2]
            data_list.append(tuple((avgQuantity,avgPrice)))
        if len(data_list) > 0 :
            filename = ''+country+'-'+month
            plot_KMeans(data_list, getClustersForMonth(month, country),filename)

# %% [markdown]
# ### Identifying most item purchases for each customer, if there are repeated customers

# %%
#CustomerID -> InvoiceNo list
customerInvoice = {}
invoiceQuantity = {}

#InvoiceNo -> StockCode
invoiceStock = {}

#StockCode -> Description (Name)
stockName = {}


# Linking data in dictionaries for CustomerID, InvoiceNo, StockCode
for i in retail_landing_df.index:
    if(not math.isnan(retail_landing_df['CustomerID'][i])):
        customerID = str(int(retail_landing_df['CustomerID'][i])).strip()
        invoiceNo = str(retail_landing_df['InvoiceNo'][i]).strip()
        stockCode = str(retail_landing_df['StockCode'][i]).strip()
        stockDesc = str(retail_landing_df['Description'][i]).strip()
        quantitiy = int(retail_landing_df['Quantity'][i])
        #if not in dict
        if customerID not in customerInvoice:
            customerInvoice[customerID] = set([invoiceNo])
        else:
            customerInvoice[customerID].add(invoiceNo)
        
        if quantitiy > 0:
            if invoiceNo not in invoiceQuantity:
                invoiceQuantity[invoiceNo] = quantitiy
            else:
                invoiceQuantity[invoiceNo] += quantitiy

# %% [markdown]
# ### Customer's Total Quantity bought till date

# %%
customerQuantity = {}

for c, invoices in customerInvoice.items():
    totalQ = 0
    for invoice in invoices:
        if invoice in invoiceQuantity:
            totalQ += invoiceQuantity[invoice]
    customerQuantity[c] = totalQ

# %%
# Items bought per Customer

itemsBoughtPerCustomer = list(customerQuantity.values())

# %% [markdown]
# ### Items bought per customer - Histogram

# %%
plt.hist(itemsBoughtPerCustomer, bins = 30)
plt.ylabel('Customers')
plt.xlabel('Items')
plt.show()
# plt.savefig('itemsBoughtPerCustomer.svg', format='svg')

# %% [markdown]
# Few customers have bought a large number of items (i.e. resellers), which skews the histogram and does not give information for other users. We filter out customers who bought less than 4000 items in their total number of visits
#
# ### Filtering items bought per customer

# %%
itemsBoughtPerCustomerFiltered = [x for x in itemsBoughtPerCustomer if x < 4000]

# %% [markdown]
# ### Items bought per customer [Filtered] - Histogram

# %%
plt.hist(itemsBoughtPerCustomerFiltered, bins=30)
plt.ylabel('Customers')
plt.xlabel('Items')
plt.show()
# plt.savefig('itemsBoughtPerCustomerFiltered.svg', format='svg')

# %% [markdown]
# # Time-series plot of transactions by day of week and month of year
#
# This was performed to verify if the results from K-means analysis rightfully identifies the busy buying pattern for both week and month

# %%
invoiceByMonth ={}
invoiceByDay={}

with open(filePath, newline='') as csvfile:
    csvReader = csv.reader(csvfile, delimiter=',', quotechar='|')
    header = next(csvReader)
    for line in csvReader:
        # Read the invoice number and the order date of the purchase
        invoice = line[0]
        # Ignore cancelled transactions
        if 'C' in invoice:
            continue
        order_date = line[3]
        order_date = time.strptime(order_date, "%d-%m-%y %H:%M")
        # Determine day of week, and month of year for the order date of the purchase
        month = calendar.month_name[order_date.tm_mon]
        day = calendar.day_name[order_date.tm_wday]
        
        # Keep track of invoices based on the month of the year of the purchase
        if month not in invoiceByMonth:
            invoiceByMonth[month] = set()
        invoiceByMonth[month].add(invoice)
        
        # Keep track of invoices based on the day of week of the purchase
        if day not in invoiceByDay:
            invoiceByDay[day] = set()
        invoiceByDay[day].add(invoice)

# Plot month of year vs number of transactions
month_x =[]
month_y = []
idx = 0
for key in invoiceByMonth:
    month_x.append(idx)
    idx+=1
    month_y.append(len(invoiceByMonth[key]))

month_ticks = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'July', 'Aug', 'Sep', 'Oct', 'Nov']
plt.plot(month_x, month_y)
plt.xlabel('Months')
plt.axhline(y=2000, color='r', linestyle='-')
plt.ylabel('No. of Transactions')
plt.title('transactions_by_month')
plt.xticks(month_x, month_ticks, rotation='vertical')
plt.savefig('transactions_by_month.svg')
plt.show()


# Plot day of week vs number of transactions
idx = 0
day_x = []
day_y = []
for key in invoiceByDay:
    day_x.append(idx)
    idx+=1
    day_y.append(len(invoiceByDay[key]))

day_ticks = ['Wed','Thur','Fri','Sun','Mon','Tue']
plt.plot(day_x, day_y)
plt.xlabel('Days')
plt.axhline(y=3500, color='r', linestyle='-')
plt.xticks(day_x, day_ticks, rotation='vertical')
plt.ylabel('No. of Transactions')
plt.title('transactions_by_day')
plt.savefig('transactions_by_day.svg')
plt.show()

# %% [markdown]
# # Time-series plot of Sales by day, week and Month
#
# This time series plots also agree with what was found previously in K-means. The daily sales data is further analyzed by using a rolling mean window of 15 days.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#Creating a new dataframe with only the required columns
quant_data = retail_landing_df[['InvoiceDate','StockCode','Quantity','UnitPrice']]

#Getting the total value of purchase per each item per a invoice number
ser_val = quant_data[['Quantity','UnitPrice']].product(axis=1)
daf = pd.DataFrame(ser_val, index=quant_data.index, columns=['TotalValue'])

#Creating a new dataframe that contains a column with purchase value per item per invoice number
final_quant_data = pd.concat([quant_data,daf], axis=1)

final_quant_data['InvoiceDate']  = final_quant_data['InvoiceDate'] .astype(str)
final_quant_data['Date'] = final_quant_data['InvoiceDate'].str.split(' ').str[0]
final_quant_data['Date'] = pd.to_datetime(final_quant_data['Date'], format = '%Y-%m-%d')
indexed_df = final_quant_data.set_index('Date')
ts = indexed_df['TotalValue']

# %%
#Aggregating the sales values by date
sale_by_day = indexed_df.groupby('Date').TotalValue.agg('sum')
#Plotting sales data per day
plt.plot(sale_by_day.index.to_pydatetime(), sale_by_day.values)
plt.title('Sales value per day')

# %%
#Aggregating the sales values by week and plotting it
ts_week = sale_by_day.resample('W').sum()
plt.plot(ts_week.index.to_pydatetime(), ts_week.values)
plt.title('Sales value per week')

# %%
#Aggregating the sales values by month and plotting it
ts_month = sale_by_day.resample('M').sum()
plt.plot(ts_month.index.to_pydatetime(), ts_month.values)
plt.title('Sales value per Month')

# %%
sale_by_day.dropna(inplace=True)
    
#Determing rolling statistics with a 15 day window
rolmean = sale_by_day.rolling(window=15,center=False).mean() 
rolstd = sale_by_day.rolling(window=15,center=False).std()

#Plot rolling statistics:
orig = plt.plot(sale_by_day.index.to_pydatetime(), sale_by_day.values, color='blue',label='Original')
mean = plt.plot(rolmean.index.to_pydatetime(), rolmean.values, color='black', label='Rolling Mean')
std = plt.plot(rolstd.index.to_pydatetime(), rolstd.values, color='red', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
#plt.savefig("Rollingstats.svg")
